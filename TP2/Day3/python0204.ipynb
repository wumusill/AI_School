# %%
import pandas as pd
import numpy as np
import requests

# %%
url = "https://finance.naver.com/sise/etf.nhn"

# %%
# 그냥 url을 넣으면 아무것도 가져오지 않음
pd.read_html(url)
# Out:
# []

# %% [markdown]
# ## requests를 통한 HTTP 요청

# %%
response = requests.get(url)
response.text
# Out:
# '<script language=javascript src=\'https://ssl.pstatic.net/imgstock/static.pc/20220923165155/js/recent_code.js\'></script>\n<script type="text/javascript">\nfunction mainSiseMove(code) {\n\tif (code==\'KONEX\') {\n\t\tdocument.location.href=\'/sise/konex.naver\';\n\t} else if(code==\'ETF\') {\n\t\tdocument.location.href=\'/sise/etf.naver\';\n    } else if(code==\'ETN\') {\n        document.location.href=\'/sise/etn.naver\';\n\t} else {\n\t\tdocument.location.href=\'/sise/sise_index.naver?code=\'+code;\n\t}\n}\n</script>\n<!--  global include -->\n\n\t\n\t\n\t\n\t\n\t\n<html lang=\'ko\'>\n<head>\n\n\n\t\n\t\n\t\t\n\t\t\t\n\t\t\t\n\t\t\t\t<title>ETF : 네이버 금융</title>\n\t\t\t\n\t\t\n\t\n\n\n\n\n\n\t\n\t\n\t\t<meta http-equiv="Content-Type" content="text/html; charset=utf-8" />\n\t\n\n\n<meta http-equiv="Content-Script-Type" content="text/javascript">\n<meta http-equiv="Content-Style-Type" content="text/css">\n<meta name="apple-mobile-web-app-title" content="네이버 금융" />\n\n\n\n\n\n\t\n\t\t<meta property="og:title" content="네이버 금융"/>\n\t\t<meta property="og:image" content="https://ssl.pstatic.net/static/m/stock/im/2016/08/og_stock-200.png"/>\n\t\t<meta property="og:url" content="https://finance.naver.com"/>\n\t\t<meta property="og:description" content="국내 해외 증시 지수, 시장지표, 뉴스, 증권사 리서치 등 제공"/>\n    \n    \n\n<meta property="og:type" content="article"/>\n<meta property="og:article:thumbnailUrl" content=""/>\n<meta property="og:article:author" content="네이버금융"/>\n<meta property="og:article:author:url" content="http://FINANCE.NAVER.COM"/>\n\n\n\n\n\n\n<link rel=\'stylesheet\' type=\'text/css\' href=\'https://ssl.pstatic.net/imgstock/static.pc/20220923165155/css/finance_header.css\'>\n\n\t\n\t\n\t\n\t\n\t\t\n\t\t<link rel="stylesheet" type="text/css" href="https://ssl.pstatic.net/imgstock/static.pc/20220923165155/css/newstock.css">\n\t\t<link rel="stylesheet" type="text/css" href="https://ssl.pstatic.net/imgstock/static.pc/20220923165155/css/common.css">\n\t\t<link rel="stylesheet" type="text/css" href="https://ssl.pstatic.net/imgstock/static.pc/20220923165155/css/layout.css">\n\t\t<link rel="stylesheet" type="text/css" href="https://ssl.pstatic.net/imgstock/static.pc/20220923165155/css/main.css">\n\t\t<link rel="stylesheet" type="text/css" href="https://ssl.pstatic.net/imgstock/static.pc/20220923165155/css/newstock2.css">\n\t\t<link rel="stylesheet" type="text/css" href="https://ssl.pstatic.net/imgstock/static.pc/20220923165155/css/newstock3.css">\n\t\t<link rel="stylesheet" type="text/css" href="https://ssl.pstatic.net/imgstock/static.pc/20220923165155/css/world.css">\n\t\t\n\t\t\t\n\t\t\t\n\t\t\t\t<script type="text/javascript" src="https://ssl.pstatic.net/imgstock/static.pc/20220923165155/js/jindo.min.ns.1.5.3.euckr.js"></script>\n\t\t\t\t<script type="text/javascript" src="https://ssl.pstatic.net/imgstock/static.pc/20220923165155/js/release/common.js"></script>\n\t\t\t\t<script type="text/javascript" src="https://ssl.pstatic.net/imgstock/static.pc/20220923165155/js/jindoComponent/jindo.Component.1.0.3.js"></script>\n\t\t\t\t<script type="text/javascript" src="https://ssl.pstatic.net/imgstock/static.pc/20220923165155/js/nhn.autocomplete.stock.js"></script>\n\t\t\t\n\t\t\n\n\t\t\n\t\t\t<link rel="stylesheet" type="text/css" href="https://ssl.pstatic.net/imgstock/static.pc/20220923165155/css/chartiq.css">\n\t\t\t<script type="text/javascript" src="https://ssl.pstatic.net/imgstock/static.pc/20220923165155/js/thirdparty/html2canvas.min.js"></script>\n\t\t\n\t\n\n<script>\n\tvar ieVersion = (function () {\n        var version = -1;\n        if (\n          navigator.appName == \'Microsoft Internet Explorer\' &&\n          navigator.userAgent.toLowerCase().indexOf(\'msie\') != -1 &&\n          new RegExp(\'MSIE ([0-9]{1,}[\\./0-9]{0,})\').exec(navigator.userAgent) != null\n        ) {\n          version = parseInt(RegExp.$1);\n        }\n        return version;\n      })();\n</script>\n\t\n\n\t<link rel="shortcut icon" href="https://ssl.pstati ...

# %%
# requests도 마찬가지
pd.read_html(response.text)
# Out:
# []

# %%
# 개발자 도구 > 네트워크 > Request URL 긁어오기
# callback 메세지 전까지! 
url = "https://finance.naver.com/api/sise/etfItemList.nhn?etfType=0&targetColumn=market_sum&sortOrder=desc"
response = requests.get(url)
response
# Out:
# <Response [200]>

# %% [markdown]
# ## JSON 타입으로 데이터 받기

# %%
etf_json = response.json()
etf_json
# Out:
# {'resultCode': 'success',
#  'result': {'etfItemList': [{'itemcode': '069500',
#     'etfTabCode': 1,
#     'itemname': 'KODEX 200',
#     'nowVal': 28390,
#     'risefall': '5',
#     'changeVal': -715,
#     'changeRate': -2.46,
#     'nav': 28412.0,
#     'threeMonthEarnRate': -7.9422,
#     'quant': 11126915,
#     'amonut': 316767,
#     'marketSum': 47383},
#    {'itemcode': '371460',
#     'etfTabCode': 4,
#     'itemname': 'TIGER 차이나전기차SOLACTIVE',
#     'nowVal': 13765,
#     'risefall': '5',
#     'changeVal': -460,
#     'changeRate': -3.23,
#     'nav': 13768.0,
#     'threeMonthEarnRate': -21.0162,
#     'quant': 2955331,
#     'amonut': 41072,
#     'marketSum': 32843},
#    {'itemcode': '423160',
#     'etfTabCode': 7,
#     'itemname': 'KODEX KOFR금리액티브(합성)',
#     'nowVal': 100855,
#     'risefall': '3',
#     'changeVal': 0,
#     'changeRate': 0.0,
#     'nav': 100862.0,
#     'threeMonthEarnRate': 0.5733,
#     'quant': 82955,
#     'amonut': 8366,
#     'marketSum': 30222},
#    {'itemcode': '252670',
#     'etfTabCode': 3,
#     'itemname': 'KODEX 200선물인버스2X',
#     'nowVal': 3835,
#     'risefall': '2',
#     'changeVal': 180,
#     'changeRate': 4.92,
#     'nav': 3857.0,
#     'threeMonthEarnRate': 15.4818,
#     'quant': 349835871,
#     'amonut': 1331364,
#     'marketSum': 23432},
#    {'itemcode': '133690',
#     'etfTabCode': 4,
#     'itemname': 'TIGER 미국나스닥100',
#     'nowVal': 72225,
#     'risefall': '5',
#     'changeVal': -355,
#     'changeRate': -0.49,
#     'nav': 72618.0,
#     'threeMonthEarnRate': 4.2771,
#     'quant': 191792,
#     'amonut': 13805,
#     'marketSum': 21140},
#    {'itemcode': '122630',
#     'etfTabCode': 3,
#     'itemname': 'KODEX 레버리지',
#     'nowVal': 11955,
#     'risefall': '5',
#     'changeVal': -615,
#     'changeRate': -4.89,
#     'nav': 11977.0,
#     'threeMonthEarnRate': -16.6446,
#     'quant': 58974824,
#     'amonut': 708491,
#     'marketSum': 20072},
#    {'itemcode': '102110',
#     'etfTabCode': 1,
#     'itemname': 'TIGER 200',
#     'nowVal': 28415,
#     'risefall': '5',
#     'changeVal': -715,
#     'changeRate': -2.45,
#     'nav': 28429.0,
#     'threeMonthEarnRate': -7.8515,
#     'quant': 1827427,
#     'amonut': 52035,
#     'marketSum': 18740},
#    {'itemcode': '157450',
#     'etfTabCode': 6,
#     'itemname': 'TIGER 단기통안채',
#     'nowVal': 101330,
#     'risefall': '2',
#     'changeVal': 5,
#     'changeRate': 0.0,
#     'nav': 101328.0,
#     'threeMonthEarnRate': 0.3764,
#     'quant': 2082044,
#     'amonut': 210981,
#     'marketSum': 18614},
#    {'itemcode': '360750',
#     'etfTabCode': 4,
#     'itemname': 'TIGER 미국S&P500',
#     'nowVal': 13150,
#     'risefall': '5',
#     'changeVal': -65,
#     'changeRate': -0.49,
#     'nav': 13194.0,
#     'threeMonthEarnRate': 4.6649,
#     'quant': 1257264,
#     'amonut': 16478,
#     'marketSum': 18121},
#    {'itemcode': '292150',
#     'etfTabCode': 2,
#     'itemname': 'TIGER TOP10',
#     'nowVal': 9330,
#     'risefall': '5',
#     'changeVal': -240,
#     'changeRate': -2.51,
#     'nav': 9323.0,
#     'threeMonthEarnRate': -7.5452,
#     'quant': 410666,
#     'amonut': 3835,
#     'marketSum': 16901},
#    {'itemcode': '214980',
#     'etfTabCode': 6,
#     'itemname': 'KODEX 단기채권PLUS',
#     'nowVal': 103975,
#     'risefall': '2',
#     'changeVal': 5,
#     'changeRate': 0.0,
#     'nav': 104035.0,
#     'threeMonthEarnRate': 0.2023,
#     'quant': 41637,
#     'amonut': 4330,
#     'marketSum': 15875},
#    {'itemcode': '102780',
#     'etfTabCode': 2,
#     'itemname': 'KODEX 삼성그룹',
#     'nowVal': 7830,
#     'risefall': '5',
#     'changeVal': -180,
#     'changeRate': -2.25,
#     'nav': 7833.0,
#     'threeMonthEarnRate': -4.0719,
#     'quant': 1254094,
#     'amonut': 9808,
#     'marketSum': 15730},
#    {'itemcode': '357870',
#     'etfTabCode': 7,
#     'itemname': 'TIGER CD금리투자KIS(합성)',
#     'nowVal': 51225,
#     'risefall': '5',
#     'changeVal': -5,
#     'changeRate': -0.01,
#     'nav': 51229.0,
#     'threeMonthEarnRate': 0.5989,
#     'quant': 21088,
#     'amonut': 1080,
#     'marketSum': 14164},
#    {'itemcode': '381170',
#     'etfTabCode': 4,
#     'itemname': 'TIGER 미국테크TOP10 INDXX',
#     'nowVal': 10580,
#     'risefall': '5',
#     'changeVal': -115,
#     'changeRate': -1.08,
#     'nav': 10667.0,
#     'threeMonthEarnRate': 3.5835,
#     'quant': 712769,
#     'amonut': 7527,
#     'marketSum': 14114},
#    {'itemcode': '381180',
#     'etfTabCode': 4,
#     'itemname': 'TIGER 미국필라델피아반도체나스닥',
#     'nowVal': 9200,
#     'risefall': '5',
#     'changeVal': -45,
#     'changeRate': -0.49,
#     'nav': 9282.0,
#     'threeMonthEarnRate': -1.3025,
#     'quant': 1132598,
#     'amonut': 10412,
#     'marketSum': 13864},
#    {'itemcode': '153130',
#     'etfTabCode': 6,
#     'itemname': 'KODEX 단기채권',
#     'nowVal': 103630,
#     'risefall': '3',
#     'changeVal': 0,
#     'changeRate': 0.0,
#     'nav': 103648.0,
#     'threeMonthEarnRate': 0.1982,
#     'quant': 897338,
#     'amonut': 92979,
#     'marketSum': 12429},
#    {'itemcode': '273130',
#     'etfTabCode': 6,
#     'itemname': 'KODEX 종합채권(AA-이상)액티브',
#     'nowVal': 98145,
#     'risefall': '2',
#     'changeVal': 75,
#     'changeRate': 0.08,
#     'nav': 98228.0,
#     'threeMonthEarnRate': -2.8626,
#     'quant': 1965,
#     'amonut': 191,
#     'marketSum': 12130},
#    {'itemcode': '278530',
#     'etfTabCode': 1,
#     'itemname': 'KODEX 200TR',
#     'nowVal': 9490,
#     'risefall': '5',
#     'changeVal': -215,
#     'changeRate': -2.22,
#     'nav': 9482.0,
#     'threeMonthEarnRate': -8.0531,
#     'quant': 3049260,
#     'amonut': 28879,
#     'marketSum': 11844},
#    {'itemcode': '305720',
#     'etfTabCode': 2,
#     'itemname': 'KODEX 2차전지산업',
#     'nowVal': 17580,
#     'risefall': '5',
#     'changeVal': -740,
#     'changeRate': -4.04,
#     'nav': 17605.0,
#     'threeMonthEarnRate': -4.2843,
#     'quant': 2629110,
#     'amonut': 47073,
#     'marketSum': 11656},
#    {'itemcode': '305540',
#     'etfTabCode': 2,
#     'itemname': 'TIGER 2차전지테마',
#     'nowVal': 16820,
#     'risefall': '5',
#     'changeVal': -830,
#     'changeRate': -4.7,
#     'nav': 16848.0,
#     'threeMonthEarnRate': -9.972,
#     'quant': 1528665,
#     'amonut': 26263,
#     'marketSum': 11421},
#    {'itemcode': '310970',
#     'etfTabCode': 1,
#     'itemname': 'TIGER MSCI Korea TR',
#     'nowVal': 11640,
#     'risefall': '5',
#     'changeVal': -245,
#     'changeRate': -2.06,
#     'nav': 11634.0,
#     'threeMonthEarnRate': -8.1885,
#     'quant': 3689,
#     'amonut': 42,
#     'marketSum': 10779},
#    {'itemcode': '148020',
#     'etfTabCode': 1,
#     'itemname': 'KBSTAR 200',
#     'nowVal': 28535,
#     'risefall': '5',
#     'changeVal': -695,
#     'changeRate': -2.38,
#     'nav': 28542.0,
#     'threeMonthEarnRate': -7.7657,
#     'quant': 170121,
#     'amonut': 4885,
#     'marketSum': 9973},
#    {'itemcode': '114800',
#     'etfTabCode': 3,
#     'itemname': 'KODEX 인버스',
#     'nowVal': 5420,
#     'risefall': '2',
#     'changeVal': 125,
#     'changeRate': 2.36,
#     'nav': 5438.0,
#     'threeMonthEarnRate': 8.2822,
#     'quant': 45240335,
#     'amonut': 244425,
#     'marketSum': 9485},
#    {'itemcode': '233740',
#     'etfTabCode': 3,
#     'itemname': 'KODEX 코스닥150레버리지',
#     'nowVal': 6270,
#     'risefall': '5',
#     'changeVal': -450,
#     'changeRate': -6.7,
#     'nav': 6277.0,
#     'threeMonthEarnRate': -21.7695,
#     'quant': 47571498,
#     'amonut': 304587,
#     'marketSum': 7775},
#    {'itemcode': '139260',
#     'etfTabCode': 2,
#     'itemname': 'TIGER 200 IT',
#     'nowVal': 24845,
#     'risefall': '5',
#     'changeVal': -795,
#     'changeRate': -3.1,
#     'nav': 24918.0,
#     'threeMonthEarnRate': -8.4286,
#     'quant': 135095,
#     'amonut': 3373,
#     'marketSum': 6728},
#    {'itemcode': '394670',
#     'etfTabCode': 4,
#     'itemname': 'TIGER 글로벌리튬&2차전지SOLACTIVE(합성)',
#     'nowVal': 10870,
#     'risefall': '5',
#     'changeVal': -150,
#     'changeRate': -1.36,
#     'nav': 10872.0,
#     'threeMonthEarnRate': 0.3186,
#     'quant': 197650,
#     'amonut': 2156,
#     'marketSum': 6226},
#    {'itemcode': '272580',
#     'etfTabCode': 6,
#     'itemname': 'TIGER 단기채권액티브',
#     'nowVal': 50730,
#     'risefall': '5',
#     'changeVal': -10,
#     'changeRate': -0.02,
#     'nav': 50737.0,
#     'threeMonthEarnRate': 0.4354,
#     'quant': 6929,
#     'amonut': 351,
#     'marketSum': 6128},
#    {'itemcode': '329750',
#     'etfTabCode': 6,
#     'itemname': 'TIGER 미국달러단기채권액티브',
#     'nowVal': 12350,
#     'risefall': '2',
#     'changeVal': 165,
#     'changeRate': 1.35,
#     'nav': 12318.0,
#     'threeMonthEarnRate': 11.025,
#     'quant': 490811,
#     'amonut': 6033,
#     'marketSum': 6065},
#    {'itemcode': '091180',
#     'etfTabCode': 2,
#     'itemname': 'KODEX 자동차',
#     'nowVal': 16825,
#     'risefall': '5',
#     'changeVal': -525,
#     'changeRate': -3.03,
#     'nav': 16831.0,
#     'threeMonthEarnRate': -2.1157,
#     'quant': 332689,
#     'amonut': 5599,
#     'marketSum': 5695},
#    {'itemcode': '152100',
#     'etfTabCode': 1,
#     'itemname': 'ARIRANG 200',
#     'nowVal': 28890,
#     'risefall': '5',
#     'changeVal': -725,
#     'changeRate': -2.45,
#     'nav': 28901.0,
#     'threeMonthEarnRate': -7.8133,
#     'quant': 57342,
#     'amonut': 1663,
#     'marketSum': 5634},
#    {'itemcode': '294400',
#     'etfTabCode': 1,
#     'itemname': 'KOSEF 200TR',
#     'nowVal': 34480,
#     'risefall': '5',
#     'changeVal': -855,
#     'changeRate': -2.42,
#     'nav': 34475.0,
#     'threeMonthEarnRate': -7.8618,
#     'quant': 383908,
#     'amonut': 13213,
#     'marketSum': 5603},
#    {'itemcode': '293180',
#     'etfTabCode': 1,
#     'itemname': 'HANARO 200',
#     'nowVal': 28460,
#     'risefall': '5',
#     'changeVal': -725,
#     'changeRate': -2.48,
#     'nav': 28486.0,
#     'threeMonthEarnRate': -7.9077,
#     'quant': 113756,
#     'amonut': 3243,
#     'marketSum': 5535},
#    {'itemcode': '278540',
#     'etfTabCode': 1,
#     'itemname': 'KODEX MSCI Korea TR',
#     'nowVal': 9250,
#     'risefall': '5',
#     'changeVal': -235,
#     'changeRate': -2.48,
#     'nav': 9265.0,
#     'threeMonthEarnRate': -8.002,
#     'quant': 400524,
#     'amonut': 3703,
#     'marketSum': 5476},
#    {'itemcode': '315930',
#     'etfTabCode': 2,
#     'itemname': 'KODEX Top5PlusTR',
#     'nowVal': 13825,
#     'risefall': '5',
#     'changeVal': -250,
#     'changeRate': -1.78,
#     'nav': 13824.0,
#     'threeMonthEarnRate': -8.3361,
#     'quant': 15778,
#     'amonut': 217,
#     'marketSum': 5323},
#    {'itemcode': '196230',
#     'etfTabCode': 6,
#     'itemname': 'KBSTAR 단기통안채',
#     'nowVal': 105575,
#     'risefall': '2',
#     'changeVal': 20,
#     'changeRate': 0.02,
#     'nav': 105570.0,
#     'threeMonthEarnRate': 0.2993,
#     'quant': 370549,
#     'amonut': 39116,
#     'marketSum': 5211},
#    {'itemcode': '379800',
#     'etfTabCode': 4,
#     'itemname': 'KODEX 미국S&P500TR',
#     'nowVal': 11655,
#     'risefall': '5',
#     'changeVal': -45,
#     'changeRate': -0.38,
#     'nav': 11676.0,
#     'threeMonthEarnRate': 4.9798,
#     'quant': 513280,
#     'amonut': 5954,
#     'marketSum': 5093},
#    {'itemcode': '360200',
#     'etfTabCode': 4,
#     'itemname': 'KINDEX 미국S&P500',
#     'nowVal': 13280,
#     'risefall': '5',
#     'changeVal': -60,
#     'changeRate': -0.45,
#     'nav': 13316.0,
#     'threeMonthEarnRate': 4.9072,
#     'quant': 129293,
#     'amonut': 1708,
#     'marketSum': 5046},
#    {'itemcode': '105190',
#     'etfTabCode': 1,
#     'itemname': 'KINDEX 200',
#     'nowVal': 28540,
#     'risefall': '5',
#     'changeVal': -685,
#     'changeRate': -2.34,
#     'nav': 28543.0,
#     'threeMonthEarnRate': -7.9093,
#     'quant': 422334,
#     'amonut': 12034,
#     'marketSum': 4752},
#    {'itemcode': '251350',
#     'etfTabCode': 4,
#     'itemname': 'KODEX 선진국MSCI World',
#     'nowVal': 19720,
#     'risefall': '5',
#     'changeVal': -55,
#     'changeRate': -0.28,
#     'nav': 19744.0,
#     'threeMonthEarnRate': 1.9855,
#     'quant': 51044,
#     'amonut': 1001,
#     'marketSum': 4674},
#    {'itemcode': '251340',
#     'etfTabCode': 3,
#     'itemname': 'KODEX 코스닥150선물인버스',
#     'nowVal': 5720,
#     'risefall': '2',
#     'changeVal': 185,
#     'changeRate': 3.34,
#     'nav': 5730.0,
#     'threeMonthEarnRate': 9.2793,
#     'quant': 80824605,
#     'amonut': 456889,
#     'marketSum': 4593},
#    {'itemcode': '367380',
#     'etfTabCode': 4,
#     'itemname': 'KINDEX 미국나스닥100',
#     'nowVal': 12395,
#     'risefall': '5',
#     'changeVal': -75,
#     'changeRate': -0.6,
#     'nav': 12479.0,
#     'threeMonthEarnRate': 4.3427,
#     'quant': 73956,
#     'amonut': 914,
#     'marketSum': 4140},
#    {'itemcode': '229200',
#     'etfTabCode': 1,
#     'itemname': 'KODEX 코스닥150',
#     'nowVal': 9550,
#     'risefall': '5',
#     'changeVal': -330,
#     'changeRate': -3.34,
#     'nav': 9612.0,
#     'threeMonthEarnRate': -10.6287,
#     'quant': 20873796,
#     'amonut': 201226,
#     'marketSum': 4102},
#    {'itemcode': '385540',
#     'etfTabCode': 6,
#     'itemname': 'KBSTAR KIS종합채권(A-이상)액티브',
#     'nowVal': 91070,
#     'risefall': '5',
#     'changeVal': -200,
#     'changeRate': -0.22,
#     'nav': 91196.0,
#     'threeMonthEarnRate': -2.1391,
#     'quant': 140,
#     'amonut': 12,
#     'marketSum': 3954},
#    {'itemcode': '364980',
#     'etfTabCode': 2,
#     'itemname': 'TIGER KRX2차전지K-뉴딜',
#     'nowVal': 12715,
#     'risefall': '5',
#     'changeVal': -430,
#     'changeRate': -3.27,
#     'nav': 12753.0,
#     'threeMonthEarnRate': -5.2954,
#     'quant': 1764472,
#     'amonut': 22708,
#     'marketSum': 3872},
#    {'itemcode': '273140',
#     'etfTabCode': 6,
#     'itemname': 'KODEX 단기변동금리부채권액티브',
#     'nowVal': 104230,
#     'risefall': '5',
#     'changeVal': -110,
#     'changeRate': -0.11,
#     'nav': 104227.0,
#     'threeMonthEarnRate': 0.7191,
#     'quant': 3507,
#     'amonut': 365,
#     'marketSum': 3862},
#    {'itemcode': '226490',
#     'etfTabCode': 1,
#     'itemname': 'KODEX 코스피',
#     'nowVal': 22045,
#     'risefall': '5',
#     'changeVal': -560,
#     'changeRate': -2.48,
#     'nav': 22057.0,
#     'threeMonthEarnRate': -6.9754,
#     'quant': 242901,
#     'amonut': 5371,
#     'marketSum': 3836},
#    {'itemcode': '143850',
#     'etfTabCode': 4,
#     'itemname': 'TIGER 미국S&P500선물(H)',
#     'nowVal': 42545,
#     'risefall': '5',
#     'changeVal': -740,
#     'changeRate': -1.71,
#     'nav': 42397.0,
#     'threeMonthEarnRate': -5.7383,
#     'quant': 257798,
#     'amonut': 10957,
#     'marketSum': 3797},
#    {'itemcode': '379810',
#     'etfTabCode': 4,
#     'itemname': 'KODEX 미국나스닥100TR',
#     'nowVal': 10630,
#     'risefall': '5',
#     'changeVal': -70,
#     'changeRate': -0.65,
#     'nav': 10705.0,
#     'threeMonthEarnRate': 4.4921,
#     'quant': 207154,
#     'amonut': 2197,
#     'marketSum': 3736},
#    {'itemcode': '314250',
#     'etfTabCode': 4,
#     'itemname': 'KODEX 미국FANG플러스(H)',
#     'nowVal': 18225,
#     'risefall': '5',
#     'changeVal': -405,
#     'changeRate': -2.17,
#     'nav': 18430.0,
#     'threeMonthEarnRate': -9.8912,
#     'quant': 75487,
#     'amonut': 1381,
#     'marketSum': 3563},
#    {'itemcode': '148070',
#     'etfTabCode': 6,
#     'itemname': 'KOSEF 국고채10년',
#     'nowVal': 103575,
#     'risefall': '5',
#     'changeVal': -365,
#     'changeRate': -0.35,
#     'nav': 103660.0,
#     'threeMonthEarnRate': -3.3072,
#     'quant': 67813,
#     'amonut': 6963,
#     'marketSum': 3480},
#    {'itemcode': '241180',
#     'etfTabCode': 4,
#     'itemname': 'TIGER 일본니케이225',
#     'nowVal': 15230,
#     'risefall': '5',
#     'changeVal': -75,
#     'changeRate': -0.49,
#     'nav': 15288.0,
#     'threeMonthEarnRate': 0.9897,
#     'quant': 11078,
#     'amonut': 167,
#     'marketSum': 3341},
#    {'itemcode': '069660',
#     'etfTabCode': 1,
#     'itemname': 'KOSEF 200',
#     'nowVal': 28425,
#     'risefall': '5',
#     'changeVal': -735,
#     'changeRate': -2.52,
#     'nav': 28428.0,
#     'threeMonthEarnRate': -7.8091,
#     'quant': 110409,
#     'amonut': 3135,
#     'marketSum': 3326},
#    {'itemcode': '371160',
#     'etfTabCode': 4,
#     'itemname': 'TIGER 차이나항셍테크',
#     'nowVal': 5665,
#     'risefall': '5',
#     'changeVal': -60,
#     'changeRate': -1.05,
#     'nav': 5635.0,
#     'threeMonthEarnRate': -19.3662,
#     'quant': 312607,
#     'amonut': 1775,
#     'marketSum': 3300},
#    {'itemcode': '213610',
#     'etfTabCode': 2,
#     'itemname': 'KODEX 삼성그룹밸류',
#     'nowVal': 7640,
#     'risefall': '5',
#     'changeVal': -190,
#     'changeRate': -2.43,
#     'nav': 7638.0,
#     'threeMonthEarnRate': -3.8675,
#     'quant': 22647,
#     'amonut': 172,
#     'marketSum': 3270},
#    {'itemcode': '190620',
#     'etfTabCode': 6,
#     'itemname': 'KINDEX 단기통안채',
#     'nowVal': 100955,
#     'risefall': '3',
#     'changeVal': 0,
#     'changeRate': 0.0,
#     'nav': 100958.0,
#     'threeMonthEarnRate': 0.3628,
#     'quant': 18502,
#     'amonut': 1868,
#     'marketSum': 2664},
#    {'itemcode': '367770',
#     'etfTabCode': 2,
#     'itemname': 'KBSTAR Fn수소경제테마',
#     'nowVal': 9050,
#     'risefall': '5',
#     'changeVal': -250,
#     'changeRate': -2.69,
#     'nav': 9051.0,
#     'threeMonthEarnRate': 0.0537,
#     'quant': 79336,
#     'amonut': 717,
#     'marketSum': 2566},
#    {'itemcode': '401470',
#     'etfTabCode': 2,
#     'itemname': 'KODEX K-메타버스액티브',
#     'nowVal': 7255,
#     'risefall': '5',
#     'changeVal': -345,
#     'changeRate': -4.54,
#     'nav': 7254.0,
#     'threeMonthEarnRate': -5.4139,
#     'quant': 407488,
#     'amonut': 2988,
#     'marketSum': 2507},
#    {'itemcode': '385550',
#     'etfTabCode': 6,
#     'itemname': 'KBSTAR KIS단기종합채권(AA-이상)액티브',
#     'nowVal': 101065,
#     'risefall': '2',
#     'changeVal': 10,
#     'changeRate': 0.01,
#     'nav': 101070.0,
#     'threeMonthEarnRate': 0.238,
#     'quant': 2509,
#     'amonut': 253,
#     'marketSum': 2411},
#    {'itemcode': '329200',
#     'etfTabCode': 2,
#     'itemname': 'TIGER 리츠부동산인프라',
#     'nowVal': 5155,
#     'risefall': '5',
#     'changeVal': -45,
#     'changeRate': -0.87,
#     'nav': 5148.0,
#     'threeMonthEarnRate': -10.0813,
#     'quant': 241846,
#     'amonut': 1239,
#     'marketSum': 2410},
#    {'itemcode': '400970',
#     'etfTabCode': 2,
#     'itemname': 'TIGER Fn메타버스',
#     'nowVal': 6835,
#     'risefall': '5',
#     'changeVal': -415,
#     'changeRate': -5.72,
#     'nav': 6836.0,
#     'threeMonthEarnRate': -9.9379,
#     'quant': 549263,
#     'amonut': 3823,
#     'marketSum': 2382},
#    {'itemcode': '368590',
#     'etfTabCode': 4,
#     'itemname': 'KBSTAR 미국나스닥100',
#     'nowVal': 12020,
#     'risefall': '5',
#     'changeVal': -45,
#     'changeRate': -0.37,
#     'nav': 12098.0,
#     'threeMonthEarnRate': 4.0893,
#     'quant': 138513,
#     'amonut': 1658,
#     'marketSum': 2332},
#    {'itemcode': '394660',
#     'etfTabCode': 4,
#     'itemname': 'TIGER 글로벌자율주행&전기차SOLACTIVE',
#     'nowVal': 9780,
#     'risefall': '5',
#     'changeVal': -90,
#     'changeRate': -0.91,
#     'nav': 9861.0,
#     'threeMonthEarnRate': 2.3858,
#     'quant': 106472,
#     'amonut': 1041,
#     'marketSum': 2328},
#    {'itemcode': '332940',
#     'etfTabCode': 1,
#     'itemname': 'HANARO MSCI Korea TR',
#     'nowVal': 11590,
#     'risefall': '5',
#     'changeVal': -315,
#     'changeRate': -2.65,
#     'nav': 11625.0,
#     'threeMonthEarnRate': -7.9274,
#     'quant': 50,
#     'amonut': 0,
#     'marketSum': 2248},
#    {'itemcode': '290130',
#     'etfTabCode': 2,
#     'itemname': 'KBSTAR ESG사회책임투자',
#     'nowVal': 9395,
#     'risefall': '5',
#     'changeVal': -195,
#     'changeRate': -2.03,
#     'nav': 9396.0,
#     'threeMonthEarnRate': -9.0996,
#     'quant': 25177,
#     'amonut': 236,
#     'marketSum': 2128},
#    {'itemcode': '414780',
#     'etfTabCode': 4,
#     'itemname': 'TIGER 차이나과창판STAR50(합성)',
#     'nowVal': 7680,
#     'risefall': '5',
#     'changeVal': -70,
#     'changeRate': -0.9,
#     'nav': 7785.0,
#     'threeMonthEarnRate': -8.9307,
#     'quant': 29406,
#     'amonut': 226,
#     'marketSum': 2100},
#    {'itemcode': '436140',
#     'etfTabCode': 6,
#     'itemname': 'SOL 종합채권(AA-이상)액티브',
#     'nowVal': 94840,
#     'risefall': '5',
#     'changeVal': -225,
#     'changeRate': -0.24,
#     'nav': 94810.0,
#     'threeMonthEarnRate': None,
#     'quant': 3016,
#     'amonut': 285,
#     'marketSum': 2080},
#    {'itemcode': '379780',
#     'etfTabCode': 4,
#     'itemname': 'KBSTAR 미국S&P500',
#     'nowVal': 11480,
#     'risefall': '5',
#     'changeVal': -30,
#     'changeRate': -0.26,
#     'nav': 11511.0,
#     'threeMonthEarnRate': 4.6268,
#     'quant': 32649,
#     'amonut': 373,
#     'marketSum': 2043},
#    {'itemcode': '364960',
#     'etfTabCode': 2,
#     'itemname': 'TIGER KRX BBIG K-뉴딜',
#     'nowVal': 6560,
#     'risefall': '5',
#     'changeVal': -130,
#     'changeRate': -1.94,
#     'nav': 6559.0,
#     'threeMonthEarnRate': -14.4502,
#     'quant': 503736,
#     'amonut': 3325,
#     'marketSum': 1952},
#    {'itemcode': '282000',
#     'etfTabCode': 3,
#     'itemname': 'KBSTAR 국고채3년선물인버스',
#     'nowVal': 106455,
#     'risefall': '5',
#     'changeVal': -200,
#     'changeRate': -0.19,
#     'nav': 106653.0,
#     'threeMonthEarnRate': 1.7312,
#     'quant': 10047,
#     'amonut': 1072,
#     'marketSum': 1844},
#    {'itemcode': '192090',
#     'etfTabCode': 4,
#     'itemname': 'TIGER 차이나CSI300',
#     'nowVal': 10140,
#     'risefall': '5',
#     'changeVal': -65,
#     'changeRate': -0.64,
#     'nav': 10177.0,
#     'threeMonthEarnRate': -9.0869,
#     'quant': 93395,
#     'amonut': 953,
#     'marketSum': 1800},
#    {'itemcode': '168580',
#     'etfTabCode': 4,
#     'itemname': 'KINDEX 중국본토CSI300',
#     'nowVal': 27335,
#     'risefall': '5',
#     'changeVal': -15,
#     'changeRate': -0.05,
#     'nav': 27441.0,
#     'threeMonthEarnRate': -10.3279,
#     'quant': 213,
#     'amonut': 5,
#     'marketSum': 1777},
#    {'itemcode': '091160',
#     'etfTabCode': 2,
#     'itemname': 'KODEX 반도체',
#     'nowVal': 22420,
#     'risefall': '5',
#     'changeVal': -550,
#     'changeRate': -2.39,
#     'nav': 22417.0,
#     'threeMonthEarnRate': -19.4318,
#     'quant': 179448,
#     'amonut': 4061,
#     'marketSum': 1760},
#    {'itemcode': '228800',
#     'etfTabCode': 2,
#     'itemname': 'TIGER 여행레저',
#     'nowVal': 3845,
#     'risefall': '5',
#     'changeVal': -95,
#     'changeRate': -2.41,
#     'nav': 3860.0,
#     'threeMonthEarnRate': -1.2532,
#     'quant': 1288903,
#     'amonut': 4968,
#     'marketSum': 1751},
#    {'itemcode': '407310',
#     'etfTabCode': 1,
#     'itemname': 'HANARO 200 TOP10',
#     'nowVal': 7210,
#     'risefall': '5',
#     'changeVal': -185,
#     'changeRate': -2.5,
#     'nav': 7233.0,
#     'threeMonthEarnRate': -5.8562,
#     'quant': 421,
#     'amonut': 3,
#     'marketSum': 1745},
#    {'itemcode': '132030',
#     'etfTabCode': 5,
#     'itemname': 'KODEX 골드선물(H)',
#     'nowVal': 10800,
#     'risefall': '5',
#     'changeVal': -100,
#     'changeRate': -0.92,
#     'nav': 10791.0,
#     'threeMonthEarnRate': -11.5978,
#     'quant': 190609,
#     'amonut': 2060,
#     'marketSum': 1706},
#    {'itemcode': '161510',
#     'etfTabCode': 2,
#     'itemname': 'ARIRANG 고배당주',
#     'nowVal': 10580,
#     'risefall': '5',
#     'changeVal': -185,
#     'changeRate': -1.72,
#     'nav': 10581.0,
#     'threeMonthEarnRate': -4.9868,
#     'quant': 49432,
#     'amonut': 522,
#     'marketSum': 1666},
#    {'itemcode': '261260',
#     'etfTabCode': 7,
#     'itemname': 'KODEX 미국달러선물인버스2X',
#     'nowVal': 5860,
#     'risefall': '5',
#     'changeVal': -170,
#     'changeRate': -2.82,
#     'nav': 5846.0,
#     'threeMonthEarnRate': -18.9517,
#     'quant': 2122412,
#     'amonut': 12544,
#     'marketSum': 1657},
#    {'itemcode': '245710',
#     'etfTabCode': 4,
#     'itemname': 'KINDEX 베트남VN30(합성)',
#     'nowVal': 20630,
#     'risefall': '5',
#     'changeVal': -90,
#     'changeRate': -0.43,
#     'nav': 20654.0,
#     'threeMonthEarnRate': 3.1872,
#     'quant': 22799,
#     'amonut': 466,
#     'marketSum': 1650},
#    {'itemcode': '412770',
#     'etfTabCode': 4,
#     'itemname': 'TIGER 글로벌메타버스액티브',
#     'nowVal': 6435,
#     'risefall': '5',
#     'changeVal': -55,
#     'changeRate': -0.85,
#     'nav': 6478.0,
#     'threeMonthEarnRate': -5.0476,
#     'quant': 222600,
#     'amonut': 1428,
#     'marketSum': 1613},
#    {'itemcode': '329650',
#     'etfTabCode': 7,
#     'itemname': 'KODEX TRF3070',
#     'nowVal': 10580,
#     'risefall': '2',
#     'changeVal': 40,
#     'changeRate': 0.38,
#     'nav': 10582.0,
#     'threeMonthEarnRate': -1.0794,
#     'quant': 38419,
#     'amonut': 404,
#     'marketSum': 1534},
#    {'itemcode': '302450',
#     'etfTabCode': 1,
#     'itemname': 'KBSTAR 코스피',
#     'nowVal': 22195,
#     'risefall': '5',
#     'changeVal': -540,
#     'changeRate': -2.38,
#     'nav': 22201.0,
#     'threeMonthEarnRate': -7.242,
#     'quant': 251432,
#     'amonut': 5572,
#     'marketSum': 1531},
#    {'itemcode': '252710',
#     'etfTabCode': 3,
#     'itemname': 'TIGER 200선물인버스2X',
#     'nowVal': 4030,
#     'risefall': '2',
#     'changeVal': 190,
#     'changeRate': 4.95,
#     'nav': 4042.0,
#     'threeMonthEarnRate': 16.012,
#     'quant': 10880492,
#     'amonut': 43600,
#     'marketSum': 1527},
#    {'itemcode': '275980',
#     'etfTabCode': 4,
#     'itemname': 'TIGER 글로벌4차산업혁신기술(합성 H)',
#     'nowVal': 13205,
#     'risefall': '5',
#     'changeVal': -175,
#     'changeRate': -1.31,
#     'nav': 13219.0,
#     'threeMonthEarnRate': -9.3496,
#     'quant': 19356,
#     'amonut': 254,
#     'marketSum': 1505},
#    {'itemcode': '091170',
#     'etfTabCode': 2,
#     'itemname': 'KODEX 은행',
#     'nowVal': 5500,
#     'risefall': '5',
#     'changeVal': -35,
#     'changeRate': -0.63,
#     'nav': 5518.0,
#     'threeMonthEarnRate': -13.9861,
#     'quant': 738674,
#     'amonut': 4037,
#     'marketSum': 1504},
#    {'itemcode': '295040',
#     'etfTabCode': 1,
#     'itemname': 'SOL 200TR',
#     'nowVal': 9870,
#     'risefall': '5',
#     'changeVal': -245,
#     'changeRate': -2.42,
#     'nav': 9865.0,
#     'threeMonthEarnRate': -7.878,
#     'quant': 1201235,
#     'amonut': 11833,
#     'marketSum': 1436},
#    {'itemcode': '261240',
#     'etfTabCode': 7,
#     'itemname': 'KODEX 미국달러선물',
#     'nowVal': 12795,
#     'risefall': '2',
#     'changeVal': 155,
#     'changeRate': 1.23,
#     'nav': 12828.0,
#     'threeMonthEarnRate': 11.1697,
#     'quant': 222919,
#     'amonut': 2843,
#     'marketSum': 1432},
#    {'itemcode': '182480',
#     'etfTabCode': 7,
#     'itemname': 'TIGER 미국MSCI리츠(합성 H)',
#     'nowVal': 11270,
#     'risefall': '5',
#     'changeVal': -375,
#     'changeRate': -3.22,
#     'nav': 11524.0,
#     'threeMonthEarnRate': -10.9982,
#     'quant': 153455,
#     'amonut': 1732,
#     'marketSum': 1403},
#    {'itemcode': '363570',
#     'etfTabCode': 6,
#     'itemname': 'KODEX 장기종합채권(AA-이상)액티브KAP',
#     'nowVal': 80335,
#     'risefall': '5',
#     'changeVal': -765,
#     'changeRate': -0.94,
#     'nav': 80986.0,
#     'threeMonthEarnRate': -4.2503,
#     'quant': 1969,
#     'amonut': 158,
#     'marketSum': 1383},
#    {'itemcode': '143860',
#     'etfTabCode': 2,
#     'itemname': 'TIGER 헬스케어',
#     'nowVal': 25085,
#     'risefall': '2',
#     'changeVal': 65,
#     'changeRate': 0.26,
#     'nav': 25230.0,
#     'threeMonthEarnRate': -12.4563,
#     'quant': 103675,
#     'amonut': 2616,
#     'marketSum': 1375},
#    {'itemcode': '356540',
#     'etfTabCode': 6,
#     'itemname': 'KINDEX 종합채권(AA-이상)KIS액티브',
#     'nowVal': 89450,
#     'risefall': '3',
#     'changeVal': 0,
#     'changeRate': 0.0,
#     'nav': 89434.0,
#     'threeMonthEarnRate': -2.2298,
#     'quant': 10,
#     'amonut': 0,
#     'marketSum': 1357},
#    {'itemcode': '409820',
#     'etfTabCode': 4,
#     'itemname': 'KODEX 미국나스닥100레버리지(합성 H)',
#     'nowVal': 4260,
#     'risefall': '5',
#     'changeVal': -190,
#     'changeRate': -4.27,
#     'nav': 4309.0,
#     'threeMonthEarnRate': -12.7451,
#     'quant': 2056366,
#     'amonut': 8782,
#     'marketSum': 1355},
#    {'itemcode': '401170',
#     'etfTabCode': 2,
#     'itemname': 'KBSTAR iSelect메타버스',
#     'nowVal': 6090,
#     'risefall': '5',
#     'changeVal': -345,
#     'changeRate': -5.36,
#     'nav': 6096.0,
#     'threeMonthEarnRate': -11.6679,
#     'quant': 145020,
#     'amonut': 900,
#     'marketSum': 1337},
#    {'itemcode': '325020',
#     'etfTabCode': 2,
#     'itemname': 'KODEX 배당가치',
#     'nowVal': 10420,
#     'risefall': '5',
#     'changeVal': -235,
#     'changeRate': -2.21,
#     'nav': 10413.0,
#     'threeMonthEarnRate': -6.4941,
#     'quant': 2216,
#     'amonut': 23,
#     'marketSum': 1334},
#    {'itemcode': '372330',
#     'etfTabCode': 4,
#     'itemname': 'KODEX 차이나항셍테크',
#     'nowVal': 5705,
#     'risefall': '5',
#     'changeVal': -20,
#     'changeRate': -0.35,
#     'nav': 5642.0,
#     'threeMonthEarnRate': -19.9301,
#     'quant': 136891,
#     'amonut': 778,
#     'marketSum': 1321},
#    {'itemcode': '326240',
#     'etfTabCode': 2,
#     'itemname': 'KBSTAR IT플러스',
#     'nowVal': 14040,
#     'risefall': '5',
#     'changeVal': -445,
#     'changeRate': -3.07,
#     'nav': 14038.0,
#     'threeMonthEarnRate': -11.0258,
#     'quant': 10174,
#     'amonut': 142,
#     'marketSum': 1303},
#    {'itemcode': '395170',
#     'etfTabCode': 2,
#     'itemname': 'KODEX Fn Top10동일가중',
#     'nowVal': 6775,
#     'risefall': '5',
#     'changeVal': -145,
#     'changeRate': -2.1,
#     'nav': 6773.0,
#     'threeMonthEarnRate': -5.2704,
#     'quant': 6511,
#     'amonut': 44,
#     'marketSum': 1301},
#    {'itemcode': '385560',
#     'etfTabCode': 6,
#     'itemname': 'KBSTAR KIS국고채30년Enhanced',
#     'nowVal': 62255,
#     'risefall': '5',
#     'changeVal': -620,
#     'changeRate': -0.99,
#     'nav': 62324.0,
#     'threeMonthEarnRate': -9.5454,
#     'quant': 53057,
#     'amonut': 3231,
#     'marketSum': 1295},
#    {'itemcode': '219480',
#     'etfTabCode': 4,
#     'itemname': 'KODEX 미국S&P500선물(H)',
#     'nowVal': 17425,
#     'risefall': '5',
#     'changeVal': -315,
#     'changeRate': -1.78,
#     'nav': 17359.0,
#     'threeMonthEarnRate': -5.8137,
#     'quant': 103822,
#     'amonut': 1805,
#     'marketSum': 1255},
#    {'itemcode': '232080',
#     'etfTabCode': 1,
#     'itemname': 'TIGER 코스닥150',
#     'nowVal': 9800,
#     'risefall': '5',
#     'changeVal': -335,
#     'changeRate': -3.31,
#     'nav': 9862.0,
#     'threeMonthEarnRate': -10.7835,
#     'quant': 200947,
#     'amonut': 1983,
#     'marketSum': 1252},
#    {'itemcode': '138540',
#     'etfTabCode': 2,
#     'itemname': 'TIGER 현대차그룹+펀더멘털',
#     'nowVal': 20665,
#     'risefall': '5',
#     'changeVal': -700,
#     'changeRate': -3.28,
#     'nav': 20667.0,
#     'threeMonthEarnRate': -1.8829,
#     'quant': 34963,
#     'amonut': 723,
#     'marketSum': 1215},
#    {'itemcode': '438330',
#     'etfTabCode': 6,
#     'itemname': 'TIGER 투자등급회사채액티브',
#     'nowVal': 98215,
#     'risefall': '2',
#     'changeVal': 80,
#     'changeRate': 0.08,
#     'nav': 98201.0,
#     'threeMonthEarnRate': None,
#     'quant': 2271,
#     'amonut': 222,
#     'marketSum': 1208},
#    {'itemcode': '328370',
#     'etfTabCode': 1,
#     'itemname': 'ARIRANG 코스피TR',
#     'nowVal': 11220,
#     'risefall': '5',
#     'changeVal': -280,
#     'changeRate': -2.43,
#     'nav': 11255.0,
#     'threeMonthEarnRate': -7.0332,
#     'quant': 9714,
#     'amonut': 109,
#     'marketSum': 1184},
#    {'itemcode': '277630',
#     'etfTabCode': 1,
#     'itemname': 'TIGER 코스피',
#     'nowVal': 22355,
#     'risefall': '5',
#     'changeVal': -550,
#     'changeRate': -2.4,
#     'nav': 22363.0,
#     'threeMonthEarnRate': -7.2297,
#     'quant': 58297,
#     'amonut': 1302,
#     'marketSum': 1140},
#    {'itemcode': '114260',
#     'etfTabCode': 6,
#     'itemname': 'KODEX 국고채3년',
#     'nowVal': 55185,
#     'risefall': '2',
#     'changeVal': 30,
#     'changeRate': 0.05,
#     'nav': 55138.0,
#     'threeMonthEarnRate': -1.014,
#     'quant': 13384,
#     'amonut': 737,
#     'marketSum': 1129},
#    {'itemcode': '411420',
#     'etfTabCode': 4,
#     'itemname': 'KODEX 미국메타버스나스닥액티브',
#     'nowVal': 6650,
#     'risefall': '5',
#     'changeVal': -60,
#     'changeRate': -0.89,
#     'nav': 6708.0,
#     'threeMonthEarnRate': -1.9723,
#     'quant': 187906,
#     'amonut': 1242,
#     'marketSum': 1124},
#    {'itemcode': '130730',
#     'etfTabCode': 6,
#     'itemname': 'KOSEF 단기자금',
#     'nowVal': 101645,
#     'risefall': '2',
#     'changeVal': 5,
#     'changeRate': 0.0,
#     'nav': 101647.0,
#     'threeMonthEarnRate': 0.3059,
#     'quant': 2067,
#     'amonut': 210,
#     'marketSum': 1114},
#    {'itemcode': '304940',
#     'etfTabCode': 4,
#     'itemname': 'KODEX 미국나스닥100선물(H)',
#     'nowVal': 14040,
#     'risefall': '5',
#     'changeVal': -255,
#     'changeRate': -1.78,
#     'nav': 14122.0,
#     'threeMonthEarnRate': -6.2931,
#     'quant': 165754,
#     'amonut': 2324,
#     'marketSum': 1088},
#    {'itemcode': '305080',
#     'etfTabCode': 6,
#     'itemname': 'TIGER 미국채10년선물',
#     'nowVal': 12440,
#     'risefall': '2',
#     'changeVal': 55,
#     'changeRate': 0.44,
#     'nav': 12429.0,
#     'threeMonthEarnRate': 5.5839,
#     'quant': 59334,
#     'amonut': 733,
#     'marketSum': 1082},
#    {'itemcode': '415340',
#     'etfTabCode': 4,
#     'itemname': 'KODEX 차이나과창판STAR50(합성)',
#     'nowVal': 7645,
#     'risefall': '5',
#     'changeVal': -145,
#     'changeRate': -1.86,
#     'nav': 7938.0,
#     'threeMonthEarnRate': -8.4069,
#     'quant': 6755,
#     'amonut': 52,
#     'marketSum': 1070},
#    {'itemcode': '150460',
#     'etfTabCode': 2,
#     'itemname': 'TIGER 중국소비테마',
#     'nowVal': 6375,
#     'risefall': '5',
#     'changeVal': -145,
#     'changeRate': -2.22,
#     'nav': 6373.0,
#     'threeMonthEarnRate': -3.7639,
#     'quant': 17005,
#     'amonut': 107,
#     'marketSum': 1056},
#    {'itemcode': '123310',
#     'etfTabCode': 3,
#     'itemname': 'TIGER 인버스',
#     'nowVal': 6050,
#     'risefall': '2',
#     'changeVal': 140,
#     'changeRate': 2.37,
#     'nav': 6064.0,
#     'threeMonthEarnRate': 8.3409,
#     'quant': 2859886,
#     'amonut': 17192,
#     'marketSum': 1047},
#    {'itemcode': '332930',
#     'etfTabCode': 1,
#     'itemname': 'HANARO 200TR',
#     'nowVal': 34485,
#     'risefall': '5',
#     'changeVal': -880,
#     'changeRate': -2.49,
#     'nav': 34513.0,
#     'threeMonthEarnRate': -7.9157,
#     'quant': 1119,
#     'amonut': 38,
#     'marketSum': 1035},
#    {'itemcode': '091230',
#     'etfTabCode': 2,
#     'itemname': 'TIGER 반도체',
#     'nowVal': 23190,
#     'risefall': '5',
#     'changeVal': -620,
#     'changeRate': -2.6,
#     'nav': 23239.0,
#     'threeMonthEarnRate': -18.5148,
#     'quant': 146514,
#     'amonut': 3412,
#     'marketSum': 1011},
#    {'itemcode': '228810',
#     'etfTabCode': 2,
#     'itemname': 'TIGER 미디어컨텐츠',
#     'nowVal': 5645,
#     'risefall': '5',
#     'changeVal': -340,
#     'changeRate': -5.68,
#     'nav': 5659.0,
#     'threeMonthEarnRate': -9.2495,
#     'quant': 294784,
#     'amonut': 1699,
#     'marketSum': 1008},
#    {'itemcode': '245340',
#     'etfTabCode': 4,
#     'itemname': 'TIGER 미국다우존스30',
#     'nowVal': 20745,
#     'risefall': '5',
#     'changeVal': -45,
#     'changeRate': -0.22,
#     'nav': 20864.0,
#     'threeMonthEarnRate': 3.0687,
#     'quant': 13840,
#     'amonut': 285,
#     'marketSum': 1004},
#    {'itemcode': '365780',
#     'etfTabCode': 6,
#     'itemname': 'KINDEX 국고채10년',
#     'nowVal': 82615,
#     'risefall': '5',
#     'changeVal': -55,
#     'changeRate': -0.07,
#     'nav': 82641.0,
#     'threeMonthEarnRate': -3.3043,
#     'quant': 3880,
#     'amonut': 317,
#     'marketSum': 1001},
#    {'itemcode': '270810',
#     'etfTabCode': 1,
#     'itemname': 'KBSTAR 코스닥150',
#     'nowVal': 9510,
#     'risefall': '5',
#     'changeVal': -315,
#     'changeRate': -3.21,
#     'nav': 9567.0,
#     'threeMonthEarnRate': -10.8844,
#     'quant': 30666,
#     'amonut': 297,
#     'marketSum': 993},
#    {'itemcode': '271050',
#     'etfTabCode': 5,
#     'itemname': 'KODEX WTI원유선물인버스(H)',
#     'nowVal': 5215,
#     'risefall': '2',
#     'changeVal': 25,
#     'changeRate': 0.48,
#     'nav': 5223.0,
#     'threeMonthEarnRate': 24.4604,
#     'quant': 1646169,
#     'amonut': 8554,
#     'marketSum': 992},
#    {'itemcode': '283580',
#     'etfTabCode': 4,
#     'itemname': 'KODEX 차이나CSI300',
#     'nowVal': 12520,
#     'risefall': '5',
#     'changeVal': -25,
#     'changeRate': -0.2,
#     'nav': 12469.0,
#     'threeMonthEarnRate': -9.3242,
#     'quant': 168523,
#     'amonut': 2097,
#     'marketSum': 926},
#    {'itemcode': '245360',
#     'etfTabCode': 4,
#     'itemname': 'TIGER 차이나HSCEI',
#     'nowVal': 9295,
#     'risefall': '5',
#     'changeVal': -50,
#     'changeRate': -0.54,
#     'nav': 9261.0,
#     'threeMonthEarnRate': -11.0424,
#     'quant': 2426,
#     'amonut': 22,
#     'marketSum': 925},
#    {'itemcode': '364970',
#     'etfTabCode': 2,
#     'itemname': 'TIGER KRX바이오K-뉴딜',
#     'nowVal': 5855,
#     'risefall': '2',
#     'changeVal': 35,
#     'changeRate': 0.6,
#     'nav': 5870.0,
#     'threeMonthEarnRate': -12.2834,
#     'quant': 486198,
#     'amonut': 2861,
#     'marketSum': 905},
#    {'itemcode': '422420',
#     'etfTabCode': 2,
#     'itemname': 'KBSTAR 2차전지액티브',
#     'nowVal': 8385,
#     'risefall': '5',
#     'changeVal': -350,
#     'changeRate': -4.01,
#     'nav': 8377.0,
#     'threeMonthEarnRate': -9.809,
#     'quant': 171570,
#     'amonut': 1457,
#     'marketSum': 902},
#    {'itemcode': '437350',
#     'etfTabCode': 6,
#     'itemname': 'KBSTAR 미국단기투자등급회사채액티브',
#     'nowVal': 10665,
#     'risefall': '2',
#     'changeVal': 105,
#     'changeRate': 0.99,
#     'nav': 10622.0,
#     'threeMonthEarnRate': None,
#     'quant': 23057,
#     'amonut': 244,
#     'marketSum': 885},
#    {'itemcode': '309230',
#     'etfTabCode': 4,
#     'itemname': 'KINDEX 미국WideMoat가치주',
#     'nowVal': 17270,
#     'risefall': '5',
#     'changeVal': -140,
#     'changeRate': -0.8,
#     'nav': 17401.0,
#     'threeMonthEarnRate': 0.3169,
#     'quant': 228934,
#     'amonut': 3950,
#     'marketSum': 829},
#    {'itemcode': '419430',
#     'etfTabCode': 4,
#     'itemname': 'KODEX 차이나2차전지MSCI(합성)',
#     'nowVal': 9590,
#     'risefall': '5',
#     'changeVal': -200,
#     'changeRate': -2.04,
#     'nav': 9614.0,
#     'threeMonthEarnRate': -20.3094,
#     'quant': 183011,
#     'amonut': 1787,
#     'marketSum': 806},
#    {'itemcode': '367760',
#     'etfTabCode': 2,
#     'itemname': 'KBSTAR Fn5G테크',
#     'nowVal': 7160,
#     'risefall': '5',
#     'changeVal': -260,
#     'changeRate': -3.5,
#     'nav': 7190.0,
#     'threeMonthEarnRate': -5.658,
#     'quant': 46686,
#     'amonut': 335,
#     'marketSum': 806},
#    {'itemcode': '139220',
#     'etfTabCode': 2,
#     'itemname': 'TIGER 200 건설',
#     'nowVal': 2435,
#     'risefall': '5',
#     'changeVal': -100,
#     'changeRate': -3.94,
#     'nav': 2442.0,
#     'threeMonthEarnRate': 2.6315,
#     'quant': 224904,
#     'amonut': 552,
#     'marketSum': 801},
#    {'itemcode': '414270',
#     'etfTabCode': 4,
#     'itemname': 'KINDEX G2전기차&자율주행액티브',
#     'nowVal': 9565,
#     'risefall': '5',
#     'changeVal': -75,
#     'changeRate': -0.78,
#     'nav': 9604.0,
#     'threeMonthEarnRate': -5.258,
#     'quant': 233701,
#     'amonut': 2260,
#     'marketSum': 784},
#    {'itemcode': '261220',
#     'etfTabCode': 5,
#     'itemname': 'KODEX WTI원유선물(H)',
#     'nowVal': 13765,
#     'risefall': '5',
#     'changeVal': -105,
#     'changeRate': -0.76,
#     'nav': 13784.0,
#     'threeMonthEarnRate': -24.3111,
#     'quant': 227569,
#     'amonut': 3146,
#     'marketSum': 774},
#    {'itemcode': '361580',
#     'etfTabCode': 1,
#     'itemname': 'KBSTAR 200TR',
#     'nowVal': 14955,
#     'risefall': '5',
#     'changeVal': -355,
#     'changeRate': -2.32,
#     'nav': 14943.0,
#     'threeMonthEarnRate': -7.8544,
#     'quant': 516164,
#     'amonut': 7699,
#     'marketSum': 770},
#    {'itemcode': '272560',
#     'etfTabCode': 6,
#     'itemname': 'KBSTAR 단기국공채액티브',
#     'nowVal': 102335,
#     'risefall': '2',
#     'changeVal': 45,
#     'changeRate': 0.04,
#     'nav': 102352.0,
#     'threeMonthEarnRate': 0.0684,
#     'quant': 8792,
#     'amonut': 899,
#     'marketSum': 765},
#    {'itemcode': '261270',
#     'etfTabCode': 7,
#     'itemname': 'KODEX 미국달러선물인버스',
#     'nowVal': 7930,
#     'risefall': '5',
#     'changeVal': -95,
#     'changeRate': -1.18,
#     'nav': 7914.0,
#     'threeMonthEarnRate': -9.9327,
#     'quant': 236728,
#     'amonut': 1882,
#     'marketSum': 764},
#    {'itemcode': '204480',
#     'etfTabCode': 4,
#     'itemname': 'TIGER 차이나CSI300레버리지(합성)',
#     'nowVal': 21780,
#     'risefall': '5',
#     'changeVal': -395,
#     'changeRate': -1.78,
#     'nav': 21927.0,
#     'threeMonthEarnRate': -18.7581,
#     'quant': 14374,
#     'amonut': 315,
#     'marketSum': 745},
#    {'itemcode': '144600',
#     'etfTabCode': 5,
#     'itemname': 'KODEX 은선물(H)',
#     'nowVal': 3620,
#     'risefall': '5',
#     'changeVal': -105,
#     'changeRate': -2.82,
#     'nav': 3601.0,
#     'threeMonthEarnRate': -13.9723,
#     'quant': 338535,
#     'amonut': 1232,
#     'marketSum': 735},
#    {'itemcode': '139280',
#     'etfTabCode': 2,
#     'itemname': 'TIGER 경기방어',
#     'nowVal': 8745,
#     'risefall': '5',
#     'changeVal': -65,
#     'changeRate': -0.74,
#     'nav': 8741.0,
#     'threeMonthEarnRate': -6.8809,
#     'quant': 3010,
#     'amonut': 26,
#     'marketSum': 701},
#    {'itemcode': '302190',
#     'etfTabCode': 6,
#     'itemname': 'TIGER 중장기국채',
#     'nowVal': 46795,
#     'risefall': '2',
#     'changeVal': 75,
#     'changeRate': 0.16,
#     'nav': 46765.0,
#     'threeMonthEarnRate': -2.1981,
#     'quant': 2963,
#     'amonut': 137,
#     'marketSum': 693},
#    {'itemcode': '337160',
#     'etfTabCode': 2,
#     'itemname': 'KODEX 200ESG',
#     'nowVal': 10480,
#     'risefall': '5',
#     'changeVal': -265,
#     'changeRate': -2.47,
#     'nav': 10477.0,
#     'threeMonthEarnRate': -7.9264,
#     'quant': 95747,
#     'amonut': 999,
#     'marketSum': 692},
#    {'itemcode': '278240',
#     'etfTabCode': 3,
#     'itemname': 'KBSTAR 코스닥150선물레버리지',
#     'nowVal': 6745,
#     'risefall': '5',
#     'changeVal': -540,
#     'changeRate': -7.41,
#     'nav': 6745.0,
#     'threeMonthEarnRate': -21.4979,
#     'quant': 246793,
#     'amonut': 1697,
#     'marketSum': 688},
#    {'itemcode': '114820',
#     'etfTabCode': 6,
#     'itemname': 'TIGER 국채3년',
#     'nowVal': 103645,
#     'risefall': '2',
#     'changeVal': 35,
#     'changeRate': 0.03,
#     'nav': 103662.0,
#     'threeMonthEarnRate': -0.8821,
#     'quant': 882,
#     'amonut': 92,
#     'marketSum': 684},
#    {'itemcode': '363510',
#     'etfTabCode': 6,
#     'itemname': 'SOL KIS단기통안채',
#     'nowVal': 101395,
#     'risefall': '2',
#     'changeVal': 15,
#     'changeRate': 0.01,
#     'nav': 101396.0,
#     'threeMonthEarnRate': 0.3812,
#     'quant': 166771,
#     'amonut': 16909,
#     'marketSum': 669},
#    {'itemcode': '200250',
#     'etfTabCode': 4,
#     'itemname': 'KOSEF 인도Nifty50(합성)',
#     'nowVal': 19545,
#     'risefall': '5',
#     'changeVal': -35,
#     'changeRate': -0.18,
#     'nav': 19677.0,
#     'threeMonthEarnRate': 13.1791,
#     'quant': 20498,
#     'amonut': 398,
#     'marketSum': 665},
#    {'itemcode': '174360',
#     'etfTabCode': 4,
#     'itemname': 'KBSTAR 중국본토대형주CSI100',
#     'nowVal': 18375,
#     'risefall': '5',
#     'changeVal': -125,
#     'changeRate': -0.68,
#     'nav': 18351.0,
#     'threeMonthEarnRate': -10.1506,
#     'quant': 2775,
#     'amonut': 50,
#     'marketSum': 662},
#    {'itemcode': '439870',
#     'etfTabCode': 6,
#     'itemname': 'KODEX 국고채30년액티브',
#     'nowVal': 87890,
#     'risefall': '5',
#     'changeVal': -660,
#     'changeRate': -0.75,
#     'nav': 87645.0,
#     'threeMonthEarnRate': None,
#     'quant': 4108,
#     'amonut': 351,
#     'marketSum': 660},
#    {'itemcode': '267770',
#     'etfTabCode': 3,
#     'itemname': 'TIGER 200선물레버리지',
#     'nowVal': 9095,
#     'risefall': '5',
#     'changeVal': -470,
#     'changeRate': -4.91,
#     'nav': 9062.0,
#     'threeMonthEarnRate': -16.2435,
#     'quant': 690512,
#     'amonut': 6326,
#     'marketSum': 646},
#    {'itemcode': '402970',
#     'etfTabCode': 4,
#     'itemname': 'KINDEX 미국고배당S&P',
#     'nowVal': 10610,
#     'risefall': '5',
#     'changeVal': -90,
#     'changeRate': -0.84,
#     'nav': 10621.0,
#     'threeMonthEarnRate': 4.0248,
#     'quant': 20221,
#     'amonut': 213,
#     'marketSum': 637},
#    {'itemcode': '322400',
#     'etfTabCode': 2,
#     'itemname': 'HANARO e커머스',
#     'nowVal': 11355,
#     'risefall': '5',
#     'changeVal': -215,
#     'changeRate': -1.86,
#     'nav': 11351.0,
#     'threeMonthEarnRate': -13.0076,
#     'quant': 9260,
#     'amonut': 105,
#     'marketSum': 636},
#    {'itemcode': '195980',
#     'etfTabCode': 4,
#     'itemname': 'ARIRANG 신흥국MSCI(합성 H)',
#     'nowVal': 8285,
#     'risefall': '5',
#     'changeVal': -55,
#     'changeRate': -0.66,
#     'nav': 8260.0,
#     'threeMonthEarnRate': -14.0207,
#     'quant': 112427,
#     'amonut': 924,
#     'marketSum': 615},
#    {'itemcode': '390390',
#     'etfTabCode': 4,
#     'itemname': 'KODEX 미국반도체MV',
#     'nowVal': 9345,
#     'risefall': '2',
#     'changeVal': 35,
#     'changeRate': 0.38,
#     'nav': 9426.0,
#     'threeMonthEarnRate': -2.1031,
#     'quant': 11313,
#     'amonut': 105,
#     'marketSum': 607},
#    {'itemcode': '266160',
#     'etfTabCode': 2,
#     'itemname': 'KBSTAR 고배당',
#     'nowVal': 10075,
#     'risefall': '5',
#     'changeVal': -250,
#     'changeRate': -2.42,
#     'nav': 10109.0,
#     'threeMonthEarnRate': -6.2217,
#     'quant': 7376,
#     'amonut': 74,
#     'marketSum': 605},
#    {'itemcode': '337150',
#     'etfTabCode': 2,
#     'itemname': 'KODEX 200exTOP',
#     'nowVal': 9805,
#     'risefall': '5',
#     'changeVal': -195,
#     'changeRate': -1.95,
#     'nav': 9812.0,
#     'threeMonthEarnRate': -8.7175,
#     'quant': 5,
#     'amonut': 0,
#     'marketSum': 598},
#    {'itemcode': '298770',
#     'etfTabCode': 4,
#     'itemname': 'KODEX 한국대만IT프리미어',
#     'nowVal': 15335,
#     'risefall': '5',
#     'changeVal': -320,
#     'changeRate': -2.04,
#     'nav': 15299.0,
#     'threeMonthEarnRate': -7.3395,
#     'quant': 20395,
#     'amonut': 314,
#     'marketSum': 598},
#    {'itemcode': '152870',
#     'etfTabCode': 1,
#     'itemname': '파워 200',
#     'nowVal': 28730,
#     'risefall': '5',
#     'changeVal': -730,
#     'changeRate': -2.48,
#     'nav': 28747.0,
#     'threeMonthEarnRate': -7.9548,
#     'quant': 2724,
#     'amonut': 79,
#     'marketSum': 589},
#    {'itemcode': '139230',
#     'etfTabCode': 2,
#     'itemname': 'TIGER 200 중공업',
#     'nowVal': 2760,
#     'risefall': '5',
#     'changeVal': -140,
#     'changeRate': -4.83,
#     'nav': 2762.0,
#     'threeMonthEarnRate': -2.8476,
#     'quant': 796081,
#     'amonut': 2230,
#     'marketSum': 587},
#    {'itemcode': '363580',
#     'etfTabCode': 2,
#     'itemname': 'KODEX 200IT TR',
#     'nowVal': 9430,
#     'risefall': '5',
#     'changeVal': -340,
#     'changeRate': -3.48,
#     'nav': 9471.0,
#     'threeMonthEarnRate': -8.5206,
#     'quant': 2772,
#     'amonut': 26,
#     'marketSum': 585},
#    {'itemcode': '385510',
#     'etfTabCode': 2,
#     'itemname': 'KODEX K-신재생에너지액티브',
#     'nowVal': 10295,
#     'risefall': '5',
#     'changeVal': -410,
#     'changeRate': -3.83,
#     'nav': 10294.0,
#     'threeMonthEarnRate': 3.7306,
#     'quant': 76953,
#     'amonut': 804,
#     'marketSum': 582},
#    {'itemcode': '417630',
#     'etfTabCode': 2,
#     'itemname': 'TIGER KEDI혁신기업ESG30',
#     'nowVal': 8240,
#     'risefall': '5',
#     'changeVal': -215,
#     'changeRate': -2.54,
#     'nav': 8258.0,
#     'threeMonthEarnRate': -6.1599,
#     'quant': 200876,
#     'amonut': 1671,
#     'marketSum': 577},
#    {'itemcode': '157490',
#     'etfTabCode': 2,
#     'itemname': 'TIGER 소프트웨어',
#     'nowVal': 8535,
#     'risefall': '5',
#     'changeVal': -240,
#     'changeRate': -2.74,
#     'nav': 8538.0,
#     'threeMonthEarnRate': -16.7063,
#     'quant': 262929,
#     'amonut': 2247,
#     'marketSum': 575},
#    {'itemcode': '117700',
#     'etfTabCode': 2,
#     'itemname': 'KODEX 건설',
#     'nowVal': 2605,
#     'risefall': '5',
#     'changeVal': -115,
#     'changeRate': -4.23,
#     'nav': 2611.0,
#     'threeMonthEarnRate': 0.0,
#     'quant': 219665,
#     'amonut': 581,
#     'marketSum': 568},
#    {'itemcode': '396500',
#     'etfTabCode': 2,
#     'itemname': 'TIGER Fn반도체TOP10',
#     'nowVal': 6210,
#     'risefall': '5',
#     'changeVal': -105,
#     'changeRate': -1.66,
#     'nav': 6209.0,
#     'threeMonthEarnRate': -14.6622,
#     'quant': 192493,
#     'amonut': 1194,
#     'marketSum': 562},
#    {'itemcode': '306520',
#     'etfTabCode': 3,
#     'itemname': 'HANARO 200선물인버스',
#     'nowVal': 12500,
#     'risefall': '2',
#     'changeVal': 270,
#     'changeRate': 2.21,
#     'nav': 12551.0,
#     'threeMonthEarnRate': 8.4219,
#     'quant': 13978,
#     'amonut': 175,
#     'marketSum': 556},
#    {'itemcode': '371470',
#     'etfTabCode': 4,
#     'itemname': 'TIGER 차이나바이오테크SOLACTIVE',
#     'nowVal': 7115,
#     'risefall': '2',
#     'changeVal': 10,
#     'changeRate': 0.14,
#     'nav': 7164.0,
#     'threeMonthEarnRate': -15.3663,
#     'quant': 17060,
#     'amonut': 121,
#     'marketSum': 555},
#    {'itemcode': '228790',
#     'etfTabCode': 2,
#     'itemname': 'TIGER 화장품',
#     'nowVal': 1970,
#     'risefall': '5',
#     'changeVal': -65,
#     'changeRate': -3.19,
#     'nav': 1963.0,
#     'threeMonthEarnRate': -6.4368,
#     'quant': 887727,
#     'amonut': 1757,
#     'marketSum': 550},
#    {'itemcode': '225040',
#     'etfTabCode': 4,
#     'itemname': 'TIGER 미국S&P500레버리지(합성 H)',
#     'nowVal': 20590,
#     'risefall': '5',
#     'changeVal': -715,
#     'changeRate': -3.36,
#     'nav': 20788.0,
#     'threeMonthEarnRate': -12.9698,
#     'quant': 34069,
#     'amonut': 700,
#     'marketSum': 544},
#    {'itemcode': '385520',
#     'etfTabCode': 2,
#     'itemname': 'KODEX K-미래차액티브',
#     'nowVal': 8420,
#     'risefall': '5',
#     'changeVal': -345,
#     'changeRate': -3.94,
#     'nav': 8419.0,
#     'threeMonthEarnRate': -7.3957,
#     'quant': 19461,
#     'amonut': 167,
#     'marketSum': 543},
#    {'itemcode': '388280',
#     'etfTabCode': 2,
#     'itemname': 'KBSTAR Fn컨택트대표',
#     'nowVal': 7360,
#     'risefall': '5',
#     'changeVal': -185,
#     'changeRate': -2.45,
#     'nav': 7359.0,
#     'threeMonthEarnRate': -5.154,
#     'quant': 13913,
#     'amonut': 101,
#     'marketSum': 539},
#    {'itemcode': '261250',
#     'etfTabCode': 7,
#     'itemname': 'KODEX 미국달러선물레버리지',
#     'nowVal': 14830,
#     'risefall': '2',
#     'changeVal': 375,
#     'changeRate': 2.59,
#     'nav': 14883.0,
#     'threeMonthEarnRate': 22.6039,
# ...
#     'changeVal': -150,
#     'changeRate': -1.69,
#     'nav': 8820.0,
#     'threeMonthEarnRate': -4.1465,
#     'quant': 594,
#     'amonut': 5,
#     'marketSum': 48},
#    {'itemcode': '307520',
#     'etfTabCode': 2,
#     'itemname': 'TIGER 지주회사',
#     'nowVal': 8730,
#     'risefall': '5',
#     'changeVal': -165,
#     'changeRate': -1.85,
#     'nav': 8727.0,
#     'threeMonthEarnRate': -10.648,
#     'quant': 411,
#     'amonut': 3,
#     'marketSum': 48},
#    {'itemcode': '280940',
#     'etfTabCode': 5,
#     'itemname': 'KODEX 골드선물인버스(H)',
#     'nowVal': 8000,
#     'risefall': '2',
#     'changeVal': 115,
#     'changeRate': 1.46,
#     'nav': 8026.0,
#     'threeMonthEarnRate': 12.9656,
#     'quant': 1197,
#     'amonut': 9,
#     'marketSum': 48},
#    {'itemcode': '140580',
#     'etfTabCode': 2,
#     'itemname': 'KBSTAR 우량업종',
#     'nowVal': 9460,
#     'risefall': '5',
#     'changeVal': -235,
#     'changeRate': -2.42,
#     'nav': 9498.0,
#     'threeMonthEarnRate': -6.3286,
#     'quant': 39,
#     'amonut': 0,
#     'marketSum': 47},
#    {'itemcode': '307510',
#     'etfTabCode': 2,
#     'itemname': 'TIGER 의료기기',
#     'nowVal': 11815,
#     'risefall': '5',
#     'changeVal': -65,
#     'changeRate': -0.55,
#     'nav': 11815.0,
#     'threeMonthEarnRate': -16.2496,
#     'quant': 2243,
#     'amonut': 26,
#     'marketSum': 47},
#    {'itemcode': '267500',
#     'etfTabCode': 6,
#     'itemname': 'KBSTAR 미국장기국채선물인버스2X(합성 H)',
#     'nowVal': 9390,
#     'risefall': '2',
#     'changeVal': 300,
#     'changeRate': 3.3,
#     'nav': 9476.0,
#     'threeMonthEarnRate': 11.9458,
#     'quant': 5322,
#     'amonut': 49,
#     'marketSum': 47},
#    {'itemcode': '243890',
#     'etfTabCode': 2,
#     'itemname': 'TIGER 200에너지화학레버리지',
#     'nowVal': 9305,
#     'risefall': '5',
#     'changeVal': -700,
#     'changeRate': -7.0,
#     'nav': 9259.0,
#     'threeMonthEarnRate': -22.9793,
#     'quant': 4558,
#     'amonut': 42,
#     'marketSum': 47},
#    {'itemcode': '426410',
#     'etfTabCode': 4,
#     'itemname': 'ARIRANG 미국대체투자Top10MV',
#     'nowVal': 10215,
#     'risefall': '2',
#     'changeVal': 10,
#     'changeRate': 0.1,
#     'nav': 10288.0,
#     'threeMonthEarnRate': 1.3406,
#     'quant': 431,
#     'amonut': 4,
#     'marketSum': 46},
#    {'itemcode': '407300',
#     'etfTabCode': 2,
#     'itemname': 'HANARO Fn골프테마',
#     'nowVal': 6120,
#     'risefall': '5',
#     'changeVal': -230,
#     'changeRate': -3.62,
#     'nav': 6160.0,
#     'threeMonthEarnRate': -12.4742,
#     'quant': 198,
#     'amonut': 1,
#     'marketSum': 46},
#    {'itemcode': '404470',
#     'etfTabCode': 2,
#     'itemname': 'HANARO KRX기후변화솔루션',
#     'nowVal': 8300,
#     'risefall': '5',
#     'changeVal': -300,
#     'changeRate': -3.49,
#     'nav': 8324.0,
#     'threeMonthEarnRate': -0.5206,
#     'quant': 94,
#     'amonut': 0,
#     'marketSum': 46},
#    {'itemcode': '157500',
#     'etfTabCode': 2,
#     'itemname': 'TIGER 증권',
#     'nowVal': 3050,
#     'risefall': '5',
#     'changeVal': -70,
#     'changeRate': -2.24,
#     'nav': 3055.0,
#     'threeMonthEarnRate': -12.6051,
#     'quant': 21666,
#     'amonut': 65,
#     'marketSum': 45},
#    {'itemcode': '267440',
#     'etfTabCode': 6,
#     'itemname': 'KBSTAR 미국장기국채선물(H)',
#     'nowVal': 8995,
#     'risefall': '5',
#     'changeVal': -165,
#     'changeRate': -1.8,
#     'nav': 8952.0,
#     'threeMonthEarnRate': -6.0995,
#     'quant': 24730,
#     'amonut': 222,
#     'marketSum': 45},
#    {'itemcode': '275750',
#     'etfTabCode': 3,
#     'itemname': 'KBSTAR 코스닥150선물인버스',
#     'nowVal': 5995,
#     'risefall': '2',
#     'changeVal': 175,
#     'changeRate': 3.01,
#     'nav': 6011.0,
#     'threeMonthEarnRate': 9.6045,
#     'quant': 73754,
#     'amonut': 440,
#     'marketSum': 45},
#    {'itemcode': '373490',
#     'etfTabCode': 2,
#     'itemname': 'KODEX K-이노베이션액티브',
#     'nowVal': 8965,
#     'risefall': '5',
#     'changeVal': -365,
#     'changeRate': -3.91,
#     'nav': 8967.0,
#     'threeMonthEarnRate': 1.2479,
#     'quant': 337,
#     'amonut': 3,
#     'marketSum': 45},
#    {'itemcode': '277650',
#     'etfTabCode': 2,
#     'itemname': 'TIGER 코스피중형주',
#     'nowVal': 12755,
#     'risefall': '5',
#     'changeVal': -355,
#     'changeRate': -2.71,
#     'nav': 12752.0,
#     'threeMonthEarnRate': -7.0543,
#     'quant': 538,
#     'amonut': 6,
#     'marketSum': 45},
#    {'itemcode': '285000',
#     'etfTabCode': 2,
#     'itemname': 'KBSTAR 200IT',
#     'nowVal': 11075,
#     'risefall': '5',
#     'changeVal': -360,
#     'changeRate': -3.15,
#     'nav': 11131.0,
#     'threeMonthEarnRate': -8.4468,
#     'quant': 866,
#     'amonut': 9,
#     'marketSum': 44},
#    {'itemcode': '098560',
#     'etfTabCode': 2,
#     'itemname': 'TIGER 방송통신',
#     'nowVal': 7630,
#     'risefall': '5',
#     'changeVal': -260,
#     'changeRate': -3.3,
#     'nav': 7629.0,
#     'threeMonthEarnRate': -10.239,
#     'quant': 1669,
#     'amonut': 12,
#     'marketSum': 44},
#    {'itemcode': '321410',
#     'etfTabCode': 7,
#     'itemname': 'KODEX 멀티에셋하이인컴(H)',
#     'nowVal': 8640,
#     'risefall': '2',
#     'changeVal': 10,
#     'changeRate': 0.12,
#     'nav': 8629.0,
#     'threeMonthEarnRate': -6.4499,
#     'quant': 35,
#     'amonut': 0,
#     'marketSum': 43},
#    {'itemcode': '275300',
#     'etfTabCode': 2,
#     'itemname': 'KODEX MSCI퀄리티',
#     'nowVal': 7180,
#     'risefall': '5',
#     'changeVal': -85,
#     'changeRate': -1.17,
#     'nav': 7144.0,
#     'threeMonthEarnRate': -8.2123,
#     'quant': 6,
#     'amonut': 0,
#     'marketSum': 43},
#    {'itemcode': '380340',
#     'etfTabCode': 2,
#     'itemname': 'KINDEX Fn5G플러스',
#     'nowVal': 6155,
#     'risefall': '5',
#     'changeVal': -215,
#     'changeRate': -3.38,
#     'nav': 6151.0,
#     'threeMonthEarnRate': -9.7095,
#     'quant': 1060,
#     'amonut': 6,
#     'marketSum': 43},
#    {'itemcode': '427120',
#     'etfTabCode': 2,
#     'itemname': 'KBSTAR Fn플랫폼테마',
#     'nowVal': 6685,
#     'risefall': '5',
#     'changeVal': -245,
#     'changeRate': -3.54,
#     'nav': 6690.0,
#     'threeMonthEarnRate': -15.6422,
#     'quant': 420,
#     'amonut': 2,
#     'marketSum': 43},
#    {'itemcode': '277640',
#     'etfTabCode': 2,
#     'itemname': 'TIGER 코스피대형주',
#     'nowVal': 10655,
#     'risefall': '5',
#     'changeVal': -345,
#     'changeRate': -3.14,
#     'nav': 10736.0,
#     'threeMonthEarnRate': -7.3295,
#     'quant': 2793,
#     'amonut': 30,
#     'marketSum': 43},
#    {'itemcode': '291890',
#     'etfTabCode': 4,
#     'itemname': 'KODEX MSCI EM선물(H)',
#     'nowVal': 7035,
#     'risefall': '5',
#     'changeVal': -95,
#     'changeRate': -1.33,
#     'nav': 7024.0,
#     'threeMonthEarnRate': -13.7848,
#     'quant': 2025,
#     'amonut': 14,
#     'marketSum': 42},
#    {'itemcode': '391680',
#     'etfTabCode': 1,
#     'itemname': 'HK 하이볼액티브',
#     'nowVal': 6780,
#     'risefall': '3',
#     'changeVal': 0,
#     'changeRate': 0.0,
#     'nav': 6651.0,
#     'threeMonthEarnRate': -8.9322,
#     'quant': 0,
#     'amonut': 0,
#     'marketSum': 41},
#    {'itemcode': '220130',
#     'etfTabCode': 4,
#     'itemname': 'SOL 중국본토 중소형 CSI500(합성 H)',
#     'nowVal': 4510,
#     'risefall': '5',
#     'changeVal': -55,
#     'changeRate': -1.2,
#     'nav': 4511.0,
#     'threeMonthEarnRate': -14.8321,
#     'quant': 184,
#     'amonut': 0,
#     'marketSum': 41},
#    {'itemcode': '298340',
#     'etfTabCode': 6,
#     'itemname': 'ARIRANG 국채선물3년',
#     'nowVal': 50710,
#     'risefall': '2',
#     'changeVal': 25,
#     'changeRate': 0.05,
#     'nav': 50882.0,
#     'threeMonthEarnRate': -1.3719,
#     'quant': 1,
#     'amonut': 0,
#     'marketSum': 41},
#    {'itemcode': '291630',
#     'etfTabCode': 3,
#     'itemname': 'KOSEF 코스닥150선물레버리지',
#     'nowVal': 2920,
#     'risefall': '5',
#     'changeVal': -225,
#     'changeRate': -7.15,
#     'nav': 2923.0,
#     'threeMonthEarnRate': -21.375,
#     'quant': 43305,
#     'amonut': 130,
#     'marketSum': 40},
#    {'itemcode': '227560',
#     'etfTabCode': 2,
#     'itemname': 'TIGER 200 생활소비재',
#     'nowVal': 8210,
#     'risefall': '5',
#     'changeVal': -145,
#     'changeRate': -1.74,
#     'nav': 8240.0,
#     'threeMonthEarnRate': -4.3504,
#     'quant': 581,
#     'amonut': 4,
#     'marketSum': 39},
#    {'itemcode': '368200',
#     'etfTabCode': 2,
#     'itemname': 'KBSTAR Fn K-뉴딜디지털플러스',
#     'nowVal': 7775,
#     'risefall': '5',
#     'changeVal': -150,
#     'changeRate': -1.89,
#     'nav': 7810.0,
#     'threeMonthEarnRate': -9.7381,
#     'quant': 90,
#     'amonut': 0,
#     'marketSum': 39},
#    {'itemcode': '301400',
#     'etfTabCode': 1,
#     'itemname': 'ARIRANG 코스닥150',
#     'nowVal': 9605,
#     'risefall': '5',
#     'changeVal': -305,
#     'changeRate': -3.08,
#     'nav': 9743.0,
#     'threeMonthEarnRate': -10.6403,
#     'quant': 6010,
#     'amonut': 57,
#     'marketSum': 38},
#    {'itemcode': '295820',
#     'etfTabCode': 1,
#     'itemname': 'ARIRANG 200동일가중',
#     'nowVal': 8505,
#     'risefall': '5',
#     'changeVal': -230,
#     'changeRate': -2.63,
#     'nav': 8535.0,
#     'threeMonthEarnRate': -7.7127,
#     'quant': 24,
#     'amonut': 0,
#     'marketSum': 38},
#    {'itemcode': '217790',
#     'etfTabCode': 2,
#     'itemname': 'TIGER 가격조정',
#     'nowVal': 18950,
#     'risefall': '5',
#     'changeVal': -815,
#     'changeRate': -4.12,
#     'nav': 18943.0,
#     'threeMonthEarnRate': -0.0759,
#     'quant': 38,
#     'amonut': 0,
#     'marketSum': 38},
#    {'itemcode': '140570',
#     'etfTabCode': 2,
#     'itemname': 'KBSTAR 수출주',
#     'nowVal': 9390,
#     'risefall': '5',
#     'changeVal': -350,
#     'changeRate': -3.59,
#     'nav': 9442.0,
#     'threeMonthEarnRate': -8.2431,
#     'quant': 1229,
#     'amonut': 11,
#     'marketSum': 38},
#    {'itemcode': '301440',
#     'etfTabCode': 2,
#     'itemname': 'ARIRANG 코스피중형주',
#     'nowVal': 9360,
#     'risefall': '5',
#     'changeVal': -265,
#     'changeRate': -2.75,
#     'nav': 9391.0,
#     'threeMonthEarnRate': -6.3261,
#     'quant': 237,
#     'amonut': 2,
#     'marketSum': 37},
#    {'itemcode': '284980',
#     'etfTabCode': 2,
#     'itemname': 'KBSTAR 200금융',
#     'nowVal': 6895,
#     'risefall': '5',
#     'changeVal': -45,
#     'changeRate': -0.65,
#     'nav': 6891.0,
#     'threeMonthEarnRate': -11.4232,
#     'quant': 1638,
#     'amonut': 11,
#     'marketSum': 37},
#    {'itemcode': '267490',
#     'etfTabCode': 6,
#     'itemname': 'KBSTAR 미국장기국채선물레버리지(합성 H)',
#     'nowVal': 7420,
#     'risefall': '5',
#     'changeVal': -295,
#     'changeRate': -3.82,
#     'nav': 7390.0,
#     'threeMonthEarnRate': -13.7507,
#     'quant': 35375,
#     'amonut': 262,
#     'marketSum': 37},
#    {'itemcode': '292340',
#     'etfTabCode': 3,
#     'itemname': '마이티 200커버드콜ATM레버리지',
#     'nowVal': 6065,
#     'risefall': '5',
#     'changeVal': -220,
#     'changeRate': -3.5,
#     'nav': 6045.0,
#     'threeMonthEarnRate': -19.3197,
#     'quant': 66,
#     'amonut': 0,
#     'marketSum': 36},
#    {'itemcode': '309210',
#     'etfTabCode': 2,
#     'itemname': 'ARIRANG KRX300헬스케어',
#     'nowVal': 7860,
#     'risefall': '2',
#     'changeVal': 75,
#     'changeRate': 0.96,
#     'nav': 7935.0,
#     'threeMonthEarnRate': -11.4335,
#     'quant': 712,
#     'amonut': 5,
#     'marketSum': 36},
#    {'itemcode': '244660',
#     'etfTabCode': 2,
#     'itemname': 'KODEX 퀄리티Plus',
#     'nowVal': 7005,
#     'risefall': '5',
#     'changeVal': -95,
#     'changeRate': -1.34,
#     'nav': 7025.0,
#     'threeMonthEarnRate': -13.4674,
#     'quant': 1247,
#     'amonut': 8,
#     'marketSum': 35},
#    {'itemcode': '376250',
#     'etfTabCode': 2,
#     'itemname': 'ARIRANG 탄소효율그린뉴딜',
#     'nowVal': 6925,
#     'risefall': '5',
#     'changeVal': -180,
#     'changeRate': -2.53,
#     'nav': 6954.0,
#     'threeMonthEarnRate': -7.5472,
#     'quant': 130,
#     'amonut': 0,
#     'marketSum': 35},
#    {'itemcode': '334690',
#     'etfTabCode': 5,
#     'itemname': 'KBSTAR 팔라듐선물(H)',
#     'nowVal': 11510,
#     'risefall': '2',
#     'changeVal': 100,
#     'changeRate': 0.88,
#     'nav': 11541.0,
#     'threeMonthEarnRate': 3.6801,
#     'quant': 2156,
#     'amonut': 24,
#     'marketSum': 35},
#    {'itemcode': '281990',
#     'etfTabCode': 2,
#     'itemname': 'KBSTAR 중소형고배당',
#     'nowVal': 9825,
#     'risefall': '5',
#     'changeVal': -240,
#     'changeRate': -2.38,
#     'nav': 9875.0,
#     'threeMonthEarnRate': -7.8297,
#     'quant': 610,
#     'amonut': 6,
#     'marketSum': 34},
#    {'itemcode': '252720',
#     'etfTabCode': 2,
#     'itemname': 'KBSTAR 모멘텀밸류',
#     'nowVal': 11310,
#     'risefall': '5',
#     'changeVal': -230,
#     'changeRate': -1.99,
#     'nav': 11346.0,
#     'threeMonthEarnRate': -5.6033,
#     'quant': 5,
#     'amonut': 0,
#     'marketSum': 34},
#    {'itemcode': '139310',
#     'etfTabCode': 5,
#     'itemname': 'TIGER 금속선물(H)',
#     'nowVal': 5620,
#     'risefall': '5',
#     'changeVal': -145,
#     'changeRate': -2.52,
#     'nav': 5675.0,
#     'threeMonthEarnRate': -11.034,
#     'quant': 5227,
#     'amonut': 29,
#     'marketSum': 34},
#    {'itemcode': '287330',
#     'etfTabCode': 2,
#     'itemname': 'KBSTAR 200생활소비재',
#     'nowVal': 6250,
#     'risefall': '5',
#     'changeVal': -120,
#     'changeRate': -1.88,
#     'nav': 6244.0,
#     'threeMonthEarnRate': -3.9216,
#     'quant': 899,
#     'amonut': 5,
#     'marketSum': 33},
#    {'itemcode': '412560',
#     'etfTabCode': 2,
#     'itemname': 'TIGER KRX BBIG K-뉴딜레버리지',
#     'nowVal': 2850,
#     'risefall': '5',
#     'changeVal': -95,
#     'changeRate': -3.23,
#     'nav': 2840.0,
#     'threeMonthEarnRate': -29.1216,
#     'quant': 65889,
#     'amonut': 188,
#     'marketSum': 31},
#    {'itemcode': '278420',
#     'etfTabCode': 2,
#     'itemname': 'ARIRANG ESG우수기업',
#     'nowVal': 7740,
#     'risefall': '5',
#     'changeVal': -160,
#     'changeRate': -2.03,
#     'nav': 7770.0,
#     'threeMonthEarnRate': -3.482,
#     'quant': 5125,
#     'amonut': 39,
#     'marketSum': 31},
#    {'itemcode': '306530',
#     'etfTabCode': 3,
#     'itemname': 'HANARO 코스닥150선물레버리지',
#     'nowVal': 5885,
#     'risefall': '5',
#     'changeVal': -365,
#     'changeRate': -5.84,
#     'nav': 5880.0,
#     'threeMonthEarnRate': -22.0213,
#     'quant': 30951,
#     'amonut': 186,
#     'marketSum': 31},
#    {'itemcode': '252730',
#     'etfTabCode': 2,
#     'itemname': 'KBSTAR 모멘텀로우볼',
#     'nowVal': 12225,
#     'risefall': '5',
#     'changeVal': -180,
#     'changeRate': -1.45,
#     'nav': 12265.0,
#     'threeMonthEarnRate': -7.009,
#     'quant': 425,
#     'amonut': 5,
#     'marketSum': 31},
#    {'itemcode': '266550',
#     'etfTabCode': 2,
#     'itemname': 'ARIRANG 중형주저변동50',
#     'nowVal': 9240,
#     'risefall': '5',
#     'changeVal': -245,
#     'changeRate': -2.58,
#     'nav': 9277.0,
#     'threeMonthEarnRate': -6.4596,
#     'quant': 68,
#     'amonut': 0,
#     'marketSum': 28},
#    {'itemcode': '280920',
#     'etfTabCode': 2,
#     'itemname': 'ARIRANG 주도업종',
#     'nowVal': 7180,
#     'risefall': '5',
#     'changeVal': -115,
#     'changeRate': -1.58,
#     'nav': 7181.0,
#     'threeMonthEarnRate': -9.2662,
#     'quant': 70,
#     'amonut': 0,
#     'marketSum': 25},
#    {'itemcode': '334700',
#     'etfTabCode': 5,
#     'itemname': 'KBSTAR 팔라듐선물인버스(H)',
#     'nowVal': 4050,
#     'risefall': '3',
#     'changeVal': 0,
#     'changeRate': 0.0,
#     'nav': 4082.0,
#     'threeMonthEarnRate': -13.9214,
#     'quant': 5695,
#     'amonut': 23,
#     'marketSum': 24},
#    {'itemcode': '285020',
#     'etfTabCode': 2,
#     'itemname': 'KBSTAR 200철강소재',
#     'nowVal': 7035,
#     'risefall': '5',
#     'changeVal': -230,
#     'changeRate': -3.17,
#     'nav': 7030.0,
#     'threeMonthEarnRate': -4.0925,
#     'quant': 972,
#     'amonut': 6,
#     'marketSum': 21},
#    {'itemcode': '315480',
#     'etfTabCode': 2,
#     'itemname': 'KBSTAR 200커뮤니케이션서비스',
#     'nowVal': 10925,
#     'risefall': '5',
#     'changeVal': -330,
#     'changeRate': -2.93,
#     'nav': 10968.0,
#     'threeMonthEarnRate': -14.5731,
#     'quant': 16,
#     'amonut': 0,
#     'marketSum': 15},
#    {'itemcode': '284990',
#     'etfTabCode': 2,
#     'itemname': 'KBSTAR 200에너지화학',
#     'nowVal': 9250,
#     'risefall': '5',
#     'changeVal': -325,
#     'changeRate': -3.39,
#     'nav': 9270.0,
#     'threeMonthEarnRate': -10.9303,
#     'quant': 1047,
#     'amonut': 9,
#     'marketSum': 11},
#    {'itemcode': '287320',
#     'etfTabCode': 2,
#     'itemname': 'KBSTAR 200산업재',
#     'nowVal': 10135,
#     'risefall': '5',
#     'changeVal': -250,
#     'changeRate': -2.41,
#     'nav': 10185.0,
#     'threeMonthEarnRate': -6.4415,
#     'quant': 6,
#     'amonut': 0,
#     'marketSum': 8},
#    {'itemcode': '287310',
#     'etfTabCode': 2,
#     'itemname': 'KBSTAR 200경기소비재',
#     'nowVal': 9040,
#     'risefall': '5',
#     'changeVal': -235,
#     'changeRate': -2.53,
#     'nav': 9041.0,
#     'threeMonthEarnRate': -2.2656,
#     'quant': 9,
#     'amonut': 0,
#     'marketSum': 7}]}}

# %% [markdown]
# ## JSON 에서 원하는 데이터 찾기

# %%
etfItemList = etf_json["result"]["etfItemList"]
print(len(etfItemList))
etfItemList[-1]
# Out:
# 622
# {'itemcode': '287310',
#  'etfTabCode': 2,
#  'itemname': 'KBSTAR 200경기소비재',
#  'nowVal': 9040,
#  'risefall': '5',
#  'changeVal': -235,
#  'changeRate': -2.53,
#  'nav': 9041.0,
#  'threeMonthEarnRate': -2.2656,
#  'quant': 9,
#  'amonut': 0,
#  'marketSum': 7}

# %% [markdown]
# ## DataFrame 으로 변환

# %%
df = pd.DataFrame(etfItemList)
df
# Out:
#     itemcode  etfTabCode               itemname  nowVal risefall  changeVal  \
# 0     069500           1              KODEX 200   28390        5       -715
# 1     371460           4  TIGER 차이나전기차SOLACTIVE   13765        5       -460
# 2     423160           7    KODEX KOFR금리액티브(합성)  100855        3          0
# 3     252670           3       KODEX 200선물인버스2X    3835        2        180
# 4     133690           4         TIGER 미국나스닥100   72225        5       -355
# ..       ...         ...                    ...     ...      ...        ...
# 617   285020           2         KBSTAR 200철강소재    7035        5       -230
# 618   315480           2    KBSTAR 200커뮤니케이션서비스   10925        5       -330
# 619   284990           2        KBSTAR 200에너지화학    9250        5       -325
# 620   287320           2          KBSTAR 200산업재   10135        5       -250
# 621   287310           2        KBSTAR 200경기소비재    9040        5       -235
#
#      changeRate       nav  threeMonthEarnRate      quant   amonut  marketSum
# 0         -2.46   28412.0             -7.9422   11126915   316767      47383
# 1         -3.23   13768.0            -21.0162    2955331    41072      32843
# 2          0.00  100862.0              0.5733      82955     8366      30222
# 3          4.92    3857.0             15.4818  349835871  1331364      23432
# 4         -0.49   72618.0              4.2771     191792    13805      21140
# ..          ...       ...                 ...        ...      ...        ...
# 617       -3.17    7030.0             -4.0925        972        6         21
# 618       -2.93   10968.0            -14.5731         16        0         15
# 619       -3.39    9270.0            -10.9303       1047        9         11
# 620       -2.41   10185.0             -6.4415          6        0          8
# 621       -2.53    9041.0             -2.2656          9        0          7
#
# [622 rows x 12 columns]

# %% [markdown]
# ## 데이터 조회

# %%
df.head(2)
# Out:
#   itemcode  etfTabCode               itemname  nowVal risefall  changeVal  \
# 0   069500           1              KODEX 200   28390        5       -715
# 1   371460           4  TIGER 차이나전기차SOLACTIVE   13765        5       -460
#
#    changeRate      nav  threeMonthEarnRate     quant  amonut  marketSum
# 0       -2.46  28412.0             -7.9422  11126915  316767      47383
# 1       -3.23  13768.0            -21.0162   2955331   41072      32843

# %%
# 파생변수
df["브랜드"] = df["itemname"].str.split(expand=True)[0]

# %%
df
# Out:
#     itemcode  etfTabCode               itemname  nowVal risefall  changeVal  \
# 0     069500           1              KODEX 200   28390        5       -715
# 1     371460           4  TIGER 차이나전기차SOLACTIVE   13765        5       -460
# 2     423160           7    KODEX KOFR금리액티브(합성)  100855        3          0
# 3     252670           3       KODEX 200선물인버스2X    3835        2        180
# 4     133690           4         TIGER 미국나스닥100   72225        5       -355
# ..       ...         ...                    ...     ...      ...        ...
# 617   285020           2         KBSTAR 200철강소재    7035        5       -230
# 618   315480           2    KBSTAR 200커뮤니케이션서비스   10925        5       -330
# 619   284990           2        KBSTAR 200에너지화학    9250        5       -325
# 620   287320           2          KBSTAR 200산업재   10135        5       -250
# 621   287310           2        KBSTAR 200경기소비재    9040        5       -235
#
#      changeRate       nav  threeMonthEarnRate      quant   amonut  marketSum  \
# 0         -2.46   28412.0             -7.9422   11126915   316767      47383
# 1         -3.23   13768.0            -21.0162    2955331    41072      32843
# 2          0.00  100862.0              0.5733      82955     8366      30222
# 3          4.92    3857.0             15.4818  349835871  1331364      23432
# 4         -0.49   72618.0              4.2771     191792    13805      21140
# ..          ...       ...                 ...        ...      ...        ...
# 617       -3.17    7030.0             -4.0925        972        6         21
# 618       -2.93   10968.0            -14.5731         16        0         15
# 619       -3.39    9270.0            -10.9303       1047        9         11
# 620       -2.41   10185.0             -6.4415          6        0          8
# 621       -2.53    9041.0             -2.2656          9        0          7
#
#         브랜드
# 0     KODEX
# 1     TIGER
# 2     KODEX
# 3     KODEX
# 4     TIGER
# ..      ...
# 617  KBSTAR
# 618  KBSTAR
# 619  KBSTAR
# 620  KBSTAR
# 621  KBSTAR
#
# [622 rows x 13 columns]

# %% [markdown]
# ## 파일명 만들기
# * 실시간으로 갱신되는 데이터는 파일명에 날짜 기록이 필요

# %%
from datetime import datetime

today = datetime.today().strftime("%Y-%m-%d")
today
# Out:
# '2022-09-28'

# %%
file_name = f"eft-{today}_raw.csv"
file_name
# Out:
# 'eft-2022-09-28_raw.csv'

# %%
df.to_csv(file_name, index=False)

# %%
# 맨 앞 0이 지워지지 않게 하기 위해 type 설정
pd.read_csv(file_name, dtype={"itemcode": "object"})
# Out:
#     itemcode  etfTabCode               itemname  nowVal  risefall  changeVal  \
# 0     069500           1              KODEX 200   28390         5       -715
# 1     371460           4  TIGER 차이나전기차SOLACTIVE   13765         5       -460
# 2     423160           7    KODEX KOFR금리액티브(합성)  100855         3          0
# 3     252670           3       KODEX 200선물인버스2X    3835         2        180
# 4     133690           4         TIGER 미국나스닥100   72225         5       -355
# ..       ...         ...                    ...     ...       ...        ...
# 617   285020           2         KBSTAR 200철강소재    7035         5       -230
# 618   315480           2    KBSTAR 200커뮤니케이션서비스   10925         5       -330
# 619   284990           2        KBSTAR 200에너지화학    9250         5       -325
# 620   287320           2          KBSTAR 200산업재   10135         5       -250
# 621   287310           2        KBSTAR 200경기소비재    9040         5       -235
#
#      changeRate       nav  threeMonthEarnRate      quant   amonut  marketSum  \
# 0         -2.46   28412.0             -7.9422   11126915   316767      47383
# 1         -3.23   13768.0            -21.0162    2955331    41072      32843
# 2          0.00  100862.0              0.5733      82955     8366      30222
# 3          4.92    3857.0             15.4818  349835871  1331364      23432
# 4         -0.49   72618.0              4.2771     191792    13805      21140
# ..          ...       ...                 ...        ...      ...        ...
# 617       -3.17    7030.0             -4.0925        972        6         21
# 618       -2.93   10968.0            -14.5731         16        0         15
# 619       -3.39    9270.0            -10.9303       1047        9         11
# 620       -2.41   10185.0             -6.4415          6        0          8
# 621       -2.53    9041.0             -2.2656          9        0          7
#
#         브랜드
# 0     KODEX
# 1     TIGER
# 2     KODEX
# 3     KODEX
# 4     TIGER
# ..      ...
# 617  KBSTAR
# 618  KBSTAR
# 619  KBSTAR
# 620  KBSTAR
# 621  KBSTAR
#
# [622 rows x 13 columns]
