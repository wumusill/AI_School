# %%
# !ls
# Out:
# Untitled.ipynb
# open
# 집계구별 일별시간대별 카드소비패턴.csv
# 숙박시설유형별_이용_총량__월・방문지・여행행태・여행유형별__20221016235423.csv

# %%
import pandas as pd

# %%
df = pd.read_csv("숙박시설유형별_이용_총량__월・방문지・여행행태・여행유형별__20221016235423.csv", encoding='cp949')

# %%
df
# Out:
#     통계분류(1)            통계분류(2)   2021 2021.1 2021.2     2021.3  2021.4  \
# 0   통계분류(1)            통계분류(2)     호텔  모텔/여관     펜션  콘도미니엄/리조트  유스 호스텔
# 1        전체                 소계  15316   5405  31896      14091    1051
# 2        월별                 1월   1211    544   1754        672      65
# 3        월별                 2월    835    193   1445        885      65
# 4        월별                 3월   1107    399   1785        762      35
# 5        월별                 4월   1129    478   2102        924     133
# 6        월별                 5월   1617    433   2252       1219     237
# 7        월별                 6월    976    363   2806       1094      46
# 8        월별                 7월   1505    365   4460       1568      37
# 9        월별                 8월   1279    422   4770       1838     155
# 10       월별                 9월   1200    427   2364       1281      80
# 11       월별                10월   1458    576   2891       1599      30
# ...

# %%
df["업종대분류(UPJONG_CLASS1)"].unique()
# Out:
# array(['요식/유흥', '유통', '스포츠/문화/레저', '의료', '주유', '음/식료품', '가정생활/서비스',
#        '전자상거래', '가전/가구', '여행/교통', '교육/학원', '미용', '의류/잡화', '자동차'],
#       dtype=object)
