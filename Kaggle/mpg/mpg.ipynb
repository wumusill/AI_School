# %% [markdown]
# [필사 원본 링크](https://www.kaggle.com/code/devanshbesain/exploration-and-analysis-auto-mpg)

# %% [markdown]
# # load data & library

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
from scipy.stats import norm
from scipy import stats
import warnings
warnings.filterwarnings('ignore')

# %%
# 차 이름을 index로 하고 data 읽기
data = pd.read_csv('../data/auto-mpg.csv', index_col='car name')

# %%
data.head()
# Out:
#                             mpg  cylinders  displacement horsepower  weight  \
# car name
# chevrolet chevelle malibu  18.0          8         307.0        130    3504
# buick skylark 320          15.0          8         350.0        165    3693
# plymouth satellite         18.0          8         318.0        150    3436
# amc rebel sst              16.0          8         304.0        150    3433
# ford torino                17.0          8         302.0        140    3449
#
#                            acceleration  model year  origin
# car name
# chevrolet chevelle malibu          12.0          70       1
# buick skylark 320                  11.5          70       1
# plymouth satellite                 11.0          70       1
# amc rebel sst                      12.0          70       1
# ford torino                        10.5          70       1

# %%
print(data.index)
print("-" * 100)
print(data.columns)
# Out:
# Index(['chevrolet chevelle malibu', 'buick skylark 320', 'plymouth satellite',
#        'amc rebel sst', 'ford torino', 'ford galaxie 500', 'chevrolet impala',
#        'plymouth fury iii', 'pontiac catalina', 'amc ambassador dpl',
#        ...
#        'chrysler lebaron medallion', 'ford granada l', 'toyota celica gt',
#        'dodge charger 2.2', 'chevrolet camaro', 'ford mustang gl', 'vw pickup',
#        'dodge rampage', 'ford ranger', 'chevy s-10'],
#       dtype='object', name='car name', length=398)
# ----------------------------------------------------------------------------------------------------
# Index(['mpg', 'cylinders', 'displacement', 'horsepower', 'weight',
#        'acceleration', 'model year', 'origin'],
#       dtype='object')

# %%
data.shape
# Out:
# (398, 8)

# %%
# NaN 없는 모습
data.isnull().any()
# Out:
# mpg             False
# cylinders       False
# displacement    False
# horsepower      False
# weight          False
# acceleration    False
# model year      False
# origin          False
# dtype: bool

# %%
data.dtypes
# Out:
# mpg             float64
# cylinders         int64
# displacement    float64
# horsepower       object
# weight            int64
# acceleration    float64
# model year        int64
# origin            int64
# dtype: object

# %%
# NaN은 없지만 결측치가 "?"로 입력된 것을 볼 수 있음
data.horsepower.unique()
# Out:
# array(['130', '165', '150', '140', '198', '220', '215', '225', '190',
#        '170', '160', '95', '97', '85', '88', '46', '87', '90', '113',
#        '200', '210', '193', '?', '100', '105', '175', '153', '180', '110',
#        '72', '86', '70', '76', '65', '69', '60', '80', '54', '208', '155',
#        '112', '92', '145', '137', '158', '167', '94', '107', '230', '49',
#        '75', '91', '122', '67', '83', '78', '52', '61', '93', '148',
#        '129', '96', '71', '98', '115', '53', '81', '79', '120', '152',
#        '102', '108', '68', '58', '149', '89', '63', '48', '66', '139',
#        '103', '125', '133', '138', '135', '142', '77', '62', '132', '84',
#        '64', '74', '116', '82'], dtype=object)

# %%
# 마력이 "?" 인 데이터 행 제거
data = data[data.horsepower != '?']

# %%
print('?' in data.horsepower)
data.shape
# Out:
# False
# (392, 8)

# %%
data.dtypes
# Out:
# mpg             float64
# cylinders         int64
# displacement    float64
# horsepower       object
# weight            int64
# acceleration    float64
# model year        int64
# origin            int64
# dtype: object

# %%
# 마력을 실수 타입으로 변경
data.horsepower = data.horsepower.astype('float')
data.dtypes
# Out:
# mpg             float64
# cylinders         int64
# displacement    float64
# horsepower      float64
# weight            int64
# acceleration    float64
# model year        int64
# origin            int64
# dtype: object

# %%
data.describe()
# Out:
#               mpg   cylinders  displacement  horsepower       weight  \
# count  392.000000  392.000000    392.000000  392.000000   392.000000
# mean    23.445918    5.471939    194.411990  104.469388  2977.584184
# std      7.805007    1.705783    104.644004   38.491160   849.402560
# min      9.000000    3.000000     68.000000   46.000000  1613.000000
# 25%     17.000000    4.000000    105.000000   75.000000  2225.250000
# 50%     22.750000    4.000000    151.000000   93.500000  2803.500000
# 75%     29.000000    8.000000    275.750000  126.000000  3614.750000
# max     46.600000    8.000000    455.000000  230.000000  5140.000000
#
#        acceleration  model year      origin
# count    392.000000  392.000000  392.000000
# mean      15.541327   75.979592    1.576531
# std        2.758864    3.683737    0.805518
# min        8.000000   70.000000    1.000000
# 25%       13.775000   73.000000    1.000000
# 50%       15.500000   76.000000    1.000000
# 75%       17.025000   79.000000    2.000000
# max       24.800000   82.000000    3.000000

# %%
# 연비의 기술통계
data["mpg"].describe()
# Out:
# count    392.000000
# mean      23.445918
# std        7.805007
# min        9.000000
# 25%       17.000000
# 50%       22.750000
# 75%       29.000000
# max       46.600000
# Name: mpg, dtype: float64

# %%
# 연비 시각화
sns.distplot(data['mpg'])
# Out:
# <AxesSubplot:xlabel='mpg', ylabel='Density'>

# %%
# 연비의 왜도와 첨도 계산
print("Skewness: %f" % data['mpg'].skew())
print("Kurtosis: %f" % data['mpg'].kurt())
# Out:
# Skewness: 0.457092
# Kurtosis: -0.515993

# %%
# Min-Max-Scaling 함수
def scale(a):
    b = (a-a.min())/(a.max()-a.min())
    return b

# %%
data_scale = data.copy()

# %%
# 위에 정의한 함수로 스케일링
data_scale ['displacement'] = scale(data_scale['displacement'])
data_scale['horsepower'] = scale(data_scale['horsepower'])
data_scale ['acceleration'] = scale(data_scale['acceleration'])
data_scale ['weight'] = scale(data_scale['weight'])
data_scale['mpg'] = scale(data_scale['mpg'])

# %%
data_scale.head()
# Out:
#                                 mpg  cylinders  displacement  horsepower  \
# car name
# chevrolet chevelle malibu  0.239362          8      0.617571    0.456522
# buick skylark 320          0.159574          8      0.728682    0.646739
# plymouth satellite         0.239362          8      0.645995    0.565217
# amc rebel sst              0.186170          8      0.609819    0.565217
# ford torino                0.212766          8      0.604651    0.510870
#
#                              weight  acceleration  model year  origin
# car name
# chevrolet chevelle malibu  0.536150      0.238095          70       1
# buick skylark 320          0.589736      0.208333          70       1
# plymouth satellite         0.516870      0.178571          70       1
# amc rebel sst              0.516019      0.238095          70       1
# ford torino                0.520556      0.148810          70       1

# %%
# origin code를 국가 이름으로 대체
data['Country_code'] = data.origin.replace([1,2,3],['USA','Europe','Japan'])
data_scale['Country_code'] = data.origin.replace([1,2,3],['USA','Europe','Japan'])

# %%
data_scale.head()
# Out:
#                                 mpg  cylinders  displacement  horsepower  \
# car name
# chevrolet chevelle malibu  0.239362          8      0.617571    0.456522
# buick skylark 320          0.159574          8      0.728682    0.646739
# plymouth satellite         0.239362          8      0.645995    0.565217
# amc rebel sst              0.186170          8      0.609819    0.565217
# ford torino                0.212766          8      0.604651    0.510870
#
#                              weight  acceleration  model year  origin  \
# car name
# chevrolet chevelle malibu  0.536150      0.238095          70       1
# buick skylark 320          0.589736      0.208333          70       1
# plymouth satellite         0.516870      0.178571          70       1
# amc rebel sst              0.516019      0.238095          70       1
# ford torino                0.520556      0.148810          70       1
#
#                           Country_code
# car name
# chevrolet chevelle malibu          USA
# buick skylark 320                  USA
# plymouth satellite                 USA
# amc rebel sst                      USA
# ford torino                        USA

# %%
# 국가별 차량 연비 시각화
var = 'Country_code'
data_plt = pd.concat([data_scale['mpg'], data_scale[var]], axis=1)
f, ax = plt.subplots(figsize=(8, 6))
fig = sns.boxplot(x=var, y="mpg", data=data_plt)
fig.axis(ymin=0, ymax=1)
plt.axhline(data_scale.mpg.mean(),color='r',linestyle='dashed',linewidth=2)

# %%
# 모델의 출시연도 별 연비 시각화
var = 'model year'
data_plt = pd.concat([data_scale['mpg'], data_scale[var]], axis=1)
f, ax = plt.subplots(figsize=(8, 6))
fig = sns.boxplot(x=var, y="mpg", data=data_plt)
fig.axis(ymin=0, ymax=1)
plt.axhline(data_scale.mpg.mean(),color='r',linestyle='dashed',linewidth=2)

# %%
# 피스톤 개수 별 연비 시각화
var = 'cylinders'
data_plt = pd.concat([data_scale['mpg'], data_scale[var]], axis=1)
f, ax = plt.subplots(figsize=(8, 6))
fig = sns.boxplot(x=var, y="mpg", data=data_plt)
fig.axis(ymin=0, ymax=1)
plt.axhline(data_scale.mpg.mean(),color='r',linestyle='dashed',linewidth=2)

# %%
# 상관계수 시각화
corrmat = data.corr()
f, ax = plt.subplots(figsize=(12, 9))
sns.heatmap(corrmat, square=True, cmap='coolwarm');

# %%
factors = ['cylinders','displacement','horsepower','acceleration','weight','mpg']
corrmat = data[factors].corr()
f, ax = plt.subplots(figsize=(12, 9))
sns.heatmap(corrmat, square=True, cmap='coolwarm');

# %%
# 이건 왜 에러일까
# 중복되는 컬럼이 있으면 생긴다고 한다 -> 중복되는 컬럼 없음
# 인덱스는 있긴 있긴하나 데이터가 다름
sns.set()
sns.pairplot(data, size=2.0, hue='Country_code')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /var/folders/ql/gbsdt1191mbf_hk8mhnwwpd80000gn/T/ipykernel_50389/960830808.py in <module>
#       3 # 인덱스는 있긴 있긴하나 데이터가 다름
#       4 sns.set()
# ----> 5 sns.pairplot(data, size=2.0, hue='Country_code')
#       6 plt.show()
#
# ~/opt/anaconda3/lib/python3.9/site-packages/seaborn/_decorators.py in inner_f(*args, **kwargs)
#      44             )
#      45         kwargs.update({k: arg for k, arg in zip(sig.parameters, args)})
# ---> 46         return f(**kwargs)
#      47     return inner_f
#      48
#
# ~/opt/anaconda3/lib/python3.9/site-packages/seaborn/axisgrid.py in pairplot(data, hue, hue_order, palette, vars, x_vars, y_vars, kind, diag_kind, markers, height, aspect, corner, dropna, plot_kws, diag_kws, grid_kws, size)
#    2128         diag_kws.setdefault("fill", True)
#    2129         diag_kws.setdefault("warn_singular", False)
# -> 2130         grid.map_diag(kdeplot, **diag_kws)
#    2131
#    2132     # Maybe plot on the off-diagonals
#
# ~/opt/anaconda3/lib/python3.9/site-packages/seaborn/axisgrid.py in map_diag(self, func, **kwargs)
#    1476             plot_kwargs.setdefault("hue_order", self._hue_order)
#    1477             plot_kwargs.setdefault("palette", self._orig_palette)
# -> 1478             func(x=vector, **plot_kwargs)
#    1479             ax.legend_ = None
#    1480
#
# ~/opt/anaconda3/lib/python3.9/site-packages/seaborn/_decorators.py in inner_f(*args, **kwargs)
#      44             )
#      45         kwargs.update({k: arg for k, arg in zip(sig.parameters, args)})
# ---> 46         return f(**kwargs)
#      47     return inner_f
#      48
#
# ~/opt/anaconda3/lib/python3.9/site-packages/seaborn/distributions.py in kdeplot(x, y, shade, vertical, kernel, bw, gridsize, cut, clip, legend, cumulative, shade_lowest, cbar, cbar_ax, cbar_kws, ax, weights, hue, palette, hue_order, hue_norm, multiple, common_norm, common_grid, levels, thresh, bw_method, bw_adjust, log_scale, color, fill, data, data2, warn_singular, **kwargs)
#    1768             plot_kws["color"] = color
#    1769
# -> 1770         p.plot_univariate_density(
#    1771             multiple=multiple,
#    1772             common_norm=common_norm,
#
# ~/opt/anaconda3/lib/python3.9/site-packages/seaborn/distributions.py in plot_univariate_density(self, multiple, common_norm, common_grid, warn_singular, fill, legend, estimate_kws, **plot_kws)
#     926
#     927         # Do the computation
# --> 928         densities = self._compute_univariate_density(
#     929             self.data_variable,
#     930             common_norm,
#
# ~/opt/anaconda3/lib/python3.9/site-packages/seaborn/distributions.py in _compute_univariate_density(self, data_variable, common_norm, common_grid, estimate_kws, log_scale, warn_singular)
#     301         densities = {}
#     302
# --> 303         for sub_vars, sub_data in self.iter_data("hue", from_comp_data=True):
#     304
#     305             # Extract the data points from this sub set and remove nulls
#
# ~/opt/anaconda3/lib/python3.9/site-packages/seaborn/_core.py in iter_data(self, grouping_vars, reverse, from_comp_data)
#     981
#     982         if from_comp_data:
# --> 983             data = self.comp_data
#     984         else:
#     985             data = self.plot_data
#
# ~/opt/anaconda3/lib/python3.9/site-packages/seaborn/_core.py in comp_data(self)
#    1055                     orig = self.plot_data[var].dropna()
#    1056                 comp_col = pd.Series(index=orig.index, dtype=float, name=var)
# -> 1057                 comp_col.loc[orig.index] = pd.to_numeric(axis.convert_units(orig))
#    1058
#    1059                 if axis.get_scale() == "log":
#
# ~/opt/anaconda3/lib/python3.9/site-packages/pandas/core/indexing.py in __setitem__(self, key, value)
#     714
#     715         iloc = self if self.name == "iloc" else self.obj.iloc
# --> 716         iloc._setitem_with_indexer(indexer, value, self.name)
#     717
#     718     def _validate_key(self, key, axis: int):
#
# ~/opt/anaconda3/lib/python3.9/site-packages/pandas/core/indexing.py in _setitem_with_indexer(self, indexer, value, name)
#    1691             self._setitem_with_indexer_split_path(indexer, value, name)
#    1692         else:
# -> 1693             self._setitem_single_block(indexer, value, name)
#    1694
#    1695     def _setitem_with_indexer_split_path(self, indexer, value, name: str):
#
# ~/opt/anaconda3/lib/python3.9/site-packages/pandas/core/indexing.py in _setitem_single_block(self, indexer, value, name)
#    1932             # setting for extensionarrays that store dicts. Need to decide
#    1933             # if it's worth supporting that.
# -> 1934             value = self._align_series(indexer, Series(value))
#    1935
#    1936         elif isinstance(value, ABCDataFrame) and name != "iloc":
#
# ~/opt/anaconda3/lib/python3.9/site-packages/pandas/core/indexing.py in _align_series(self, indexer, ser, multiindex_indexer)
#    2094                 if obj.ndim == 2 and is_empty_indexer(indexer[0], ser._values):
#    2095                     return ser._values.copy()
# -> 2096                 ser = ser.reindex(obj.axes[0][indexer[0]], copy=True)._values
#    2097
#    2098                 # single indexer
#
# ~/opt/anaconda3/lib/python3.9/site-packages/pandas/core/series.py in reindex(self, *args, **kwargs)
#    4670                 )
#    4671             kwargs.update({"index": index})
# -> 4672         return super().reindex(**kwargs)
#    4673
#    4674     @deprecate_nonkeyword_arguments(version=None, allowed_args=["self", "labels"])
#
# ~/opt/anaconda3/lib/python3.9/site-packages/pandas/core/generic.py in reindex(self, *args, **kwargs)
#    4964
#    4965         # perform the reindex on the axes
# -> 4966         return self._reindex_axes(
#    4967             axes, level, limit, tolerance, method, fill_value, copy
#    4968         ).__finalize__(self, method="reindex")
#
# ~/opt/anaconda3/lib/python3.9/site-packages/pandas/core/generic.py in _reindex_axes(self, axes, level, limit, tolerance, method, fill_value, copy)
#    4984
#    4985             axis = self._get_axis_number(a)
# -> 4986             obj = obj._reindex_with_indexers(
#    4987                 {axis: [new_index, indexer]},
#    4988                 fill_value=fill_value,
#
# ~/opt/anaconda3/lib/python3.9/site-packages/pandas/core/generic.py in _reindex_with_indexers(self, reindexers, fill_value, copy, allow_dups)
#    5030
#    5031             # TODO: speed up on homogeneous DataFrame objects (see _reindex_multi)
# -> 5032             new_data = new_data.reindex_indexer(
#    5033                 index,
#    5034                 indexer,
#
# ~/opt/anaconda3/lib/python3.9/site-packages/pandas/core/internals/managers.py in reindex_indexer(self, new_axis, indexer, axis, fill_value, allow_dups, copy, consolidate, only_slice, use_na_proxy)
#     674         # some axes don't allow reindexing with dups
#     675         if not allow_dups:
# --> 676             self.axes[axis]._validate_can_reindex(indexer)
#     677
#     678         if axis >= self.ndim:
#
# ~/opt/anaconda3/lib/python3.9/site-packages/pandas/core/indexes/base.py in _validate_can_reindex(self, indexer)
#    4119         # trying to reindex on an axis with duplicates
#    4120         if not self._index_as_unique and len(indexer):
# -> 4121             raise ValueError("cannot reindex on an axis with duplicate labels")
#    4122
#    4123     def reindex(
#
# ValueError: cannot reindex on an axis with duplicate labels

# %%
# 같은 차종을 여러 방식으로 표현
data[data.index.str.contains("subaru")]
# Out:
#             mpg  cylinders  displacement  horsepower  weight  acceleration  \
# car name
# subaru     26.0          4         108.0        93.0    2391          15.5
# subaru dl  30.0          4          97.0        67.0    1985          16.4
# subaru dl  33.8          4          97.0        67.0    2145          18.0
# subaru     32.3          4          97.0        67.0    2065          17.8
#
#            model year  origin Country_code
# car name
# subaru             74       3        Japan
# subaru dl          77       3        Japan
# subaru dl          80       3        Japan
# subaru             81       3        Japan

# %%
# 통일
data[data.index.str.contains('subaru')].index.str.replace('(.*)', 'subaru dl')
# Out:
# Index(['subaru dlsubaru dl', 'subaru dlsubaru dl', 'subaru dlsubaru dl',
#        'subaru dlsubaru dl'],
#       dtype='object', name='car name')

# %%
# 특수문자 추출
data['Company_Name'] = data.index.str.extract('(^.*?)\s')

# %%
# 회사명 오타 모두 수정
data['Company_Name'] = data['Company_Name'].replace(['volkswagen','vokswagen','vw'],'VW')
data['Company_Name'] = data['Company_Name'].replace('maxda','mazda')
data['Company_Name'] = data['Company_Name'].replace('toyouta','toyota')
data['Company_Name'] = data['Company_Name'].replace('mercedes','mercedes-benz')
data['Company_Name'] = data['Company_Name'].replace('nissan','datsun')
data['Company_Name'] = data['Company_Name'].replace('capri','ford')
data['Company_Name'] = data['Company_Name'].replace(['chevroelt','chevy'],'chevrolet')
data['Company_Name'].fillna(value = 'subaru',inplace=True)

# %%
# 회사별 연비
var = 'Company_Name'
data_plt = pd.concat([data_scale['mpg'], data[var]], axis=1)
f, ax = plt.subplots(figsize=(20,10))
fig = sns.boxplot(x=var, y="mpg", data=data_plt)
fig.set_xticklabels(ax.get_xticklabels(),rotation=30)
fig.axis(ymin=0, ymax=1)
plt.axhline(data_scale.mpg.mean(),color='r',linestyle='dashed',linewidth=2)

# %%
data.Company_Name.isnull().any()
# Out:
# False

# %%
# 연비 최솟값 데이터
var='mpg'
data[data[var]== data[var].min()]
# Out:
#           mpg  cylinders  displacement  horsepower  weight  acceleration  \
# car name
# hi 1200d  9.0          8         304.0       193.0    4732          18.5
#
#           model year  origin Country_code Company_Name
# car name
# hi 1200d          70       1          USA       subaru

# %%
# 연비 최댓값 데이터
data[data[var]== data[var].max()]
# Out:
#             mpg  cylinders  displacement  horsepower  weight  acceleration  \
# car name
# mazda glc  46.6          4          86.0        65.0    2110          17.9
#
#            model year  origin Country_code Company_Name
# car name
# mazda glc          80       3        Japan       subaru

# %%
# displacement 최솟값 데이터
var='displacement'
data[data[var]== data[var].min()]
# Out:
#            mpg  cylinders  displacement  horsepower  weight  acceleration  \
# car name
# fiat 128  29.0          4          68.0        49.0    1867          19.5
#
#           model year  origin Country_code Company_Name
# car name
# fiat 128          73       2       Europe       subaru

# %%
# displacement 최댓값 데이터
data[data[var]== data[var].max()]
# Out:
#                            mpg  cylinders  displacement  horsepower  weight  \
# car name
# pontiac catalina          14.0          8         455.0       225.0    4425
# buick estate wagon (sw)   14.0          8         455.0       225.0    3086
# buick electra 225 custom  12.0          8         455.0       225.0    4951
#
#                           acceleration  model year  origin Country_code  \
# car name
# pontiac catalina                  10.0          70       1          USA
# buick estate wagon (sw)           10.0          70       1          USA
# buick electra 225 custom          11.0          73       1          USA
#
#                          Company_Name
# car name
# pontiac catalina               subaru
# buick estate wagon (sw)        subaru
# buick electra 225 custom       subaru

# %%
# 마력 최솟값 데이터
var='horsepower'
data[data[var]== data[var].min()]
# Out:
#                                mpg  cylinders  displacement  horsepower  \
# car name
# volkswagen 1131 deluxe sedan  26.0          4          97.0        46.0
# volkswagen super beetle       26.0          4          97.0        46.0
#
#                               weight  acceleration  model year  origin  \
# car name
# volkswagen 1131 deluxe sedan    1835          20.5          70       2
# volkswagen super beetle         1950          21.0          73       2
#
#                              Country_code Company_Name
# car name
# volkswagen 1131 deluxe sedan       Europe       subaru
# volkswagen super beetle            Europe       subaru

# %%
# 마력 최댓값 데이터
data[data[var]== data[var].max()]
# Out:
#                      mpg  cylinders  displacement  horsepower  weight  \
# car name
# pontiac grand prix  16.0          8         400.0       230.0    4278
#
#                     acceleration  model year  origin Country_code Company_Name
# car name
# pontiac grand prix           9.5          73       1          USA       subaru

# %%
# 무게 최솟값 데이터
var='weight'
data[data[var]== data[var].min()]
# Out:
#               mpg  cylinders  displacement  horsepower  weight  acceleration  \
# car name
# datsun 1200  35.0          4          72.0        69.0    1613          18.0
#
#              model year  origin Country_code Company_Name
# car name
# datsun 1200          71       3        Japan       subaru

# %%
# 무게 최댓값 데이터
data[data[var]== data[var].max()]
# Out:
#                       mpg  cylinders  displacement  horsepower  weight  \
# car name
# pontiac safari (sw)  13.0          8         400.0       175.0    5140
#
#                      acceleration  model year  origin Country_code  \
# car name
# pontiac safari (sw)          12.0          71       1          USA
#
#                     Company_Name
# car name
# pontiac safari (sw)       subaru

# %%
# acceleration 최솟값 데이터
var='acceleration'
data[data[var]== data[var].min()]
# Out:
#                      mpg  cylinders  displacement  horsepower  weight  \
# car name
# plymouth 'cuda 340  14.0          8         340.0       160.0    3609
#
#                     acceleration  model year  origin Country_code Company_Name
# car name
# plymouth 'cuda 340           8.0          70       1          USA       subaru

# %%
# acceleration 최댓값 데이터
data[data[var]== data[var].max()]
# Out:
#               mpg  cylinders  displacement  horsepower  weight  acceleration  \
# car name
# peugeot 504  27.2          4         141.0        71.0    3190          24.8
#
#              model year  origin Country_code Company_Name
# car name
# peugeot 504          79       2       Europe       subaru

# %%
# 마력과 연비의 관계 시각화
var = 'horsepower'
plot = sns.lmplot(var,'mpg',data=data,hue='Country_code')
plot.set(ylim = (0,50))

# %%
# displacement와 연비의 관계 시각화
var = 'displacement'
plot = sns.lmplot(var,'mpg',data=data,hue='Country_code')
plot.set(ylim = (0,50))

# %%
# 무게와 연비의 관계 시각화
var = 'weight'
plot = sns.lmplot(var,'mpg',data=data,hue='Country_code')
plot.set(ylim = (0,50))

# %%
# acceleration과 연비 관계 시각화
var = 'acceleration'
plot = sns.lmplot(var,'mpg',data=data,hue='Country_code')
plot.set(ylim = (0,50))

# %%
# 파생변수 : 중량 대비 출력
data['Power_to_weight'] = ((data.horsepower*0.7457)/data.weight)

# %%
data.sort_values(by='Power_to_weight', ascending=False).head()
# Out:
#                           mpg  cylinders  displacement  horsepower  weight  \
# car name
# buick estate wagon (sw)  14.0          8         455.0       225.0    3086
# pontiac grand prix       16.0          8         400.0       230.0    4278
# pontiac catalina         14.0          8         455.0       225.0    4425
# bmw 2002                 26.0          4         121.0       113.0    2234
# chevrolet impala         14.0          8         454.0       220.0    4354
#
#                          acceleration  model year  origin Country_code  \
# car name
# buick estate wagon (sw)          10.0          70       1          USA
# pontiac grand prix                9.5          73       1          USA
# pontiac catalina                 10.0          70       1          USA
# bmw 2002                         12.5          70       2       Europe
# chevrolet impala                  9.0          70       1          USA
#
#                         Company_Name  Power_to_weight
# car name
# buick estate wagon (sw)       subaru         0.054369
# pontiac grand prix            subaru         0.040091
# pontiac catalina              subaru         0.037917
# bmw 2002                      subaru         0.037719
# chevrolet impala              subaru         0.037679

# %%
# ML models
from sklearn.preprocessing import StandardScaler
from sklearn.tree import DecisionTreeRegressor
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error
from math import sqrt
from sklearn.ensemble import GradientBoostingRegressor
from sklearn.model_selection import GridSearchCV
from sklearn.model_selection import KFold

# %%
# feature & label
factors = ['cylinders','displacement','horsepower','acceleration','weight','origin','model year']
X = pd.DataFrame(data[factors].copy())
y = data['mpg'].copy()

# %%
# feature scaling
X = StandardScaler().fit_transform(X)

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.33, random_state=324)
X_train.shape[0] == y_train.shape[0]
# Out:
# True

# %%
regressor = LinearRegression()

# %%
regressor.get_params()
# Out:
# {'copy_X': True,
#  'fit_intercept': True,
#  'n_jobs': None,
#  'normalize': 'deprecated',
#  'positive': False}

# %%
# 회귀 학습
regressor.fit(X_train,y_train)
# Out:
# LinearRegression()

# %%
# 예측
y_predicted = regressor.predict(X_test)

# %%
# 오차 계산
rmse = sqrt(mean_squared_error(y_true=y_test,y_pred=y_predicted))
rmse
# Out:
# 3.4867296149015616

# %%
gb_regressor = GradientBoostingRegressor(n_estimators=4000)
gb_regressor.fit(X_train,y_train)
# Out:
# GradientBoostingRegressor(n_estimators=4000)

# %%
gb_regressor.get_params()
# Out:
# {'alpha': 0.9,
#  'ccp_alpha': 0.0,
#  'criterion': 'friedman_mse',
#  'init': None,
#  'learning_rate': 0.1,
#  'loss': 'squared_error',
#  'max_depth': 3,
#  'max_features': None,
#  'max_leaf_nodes': None,
#  'min_impurity_decrease': 0.0,
#  'min_samples_leaf': 1,
#  'min_samples_split': 2,
#  'min_weight_fraction_leaf': 0.0,
#  'n_estimators': 4000,
#  'n_iter_no_change': None,
#  'random_state': None,
#  'subsample': 1.0,
#  'tol': 0.0001,
#  'validation_fraction': 0.1,
#  'verbose': 0,
#  'warm_start': False}

# %%
y_predicted_gbr = gb_regressor.predict(X_test)

# %%
rmse_bgr = sqrt(mean_squared_error(y_true=y_test,y_pred=y_predicted_gbr))
rmse_bgr
# Out:
# 2.670425912560041

# %%
fi= pd.Series(gb_regressor.feature_importances_,index=factors)
fi.plot.barh()
# Out:
# <AxesSubplot:>

# %%
from sklearn.decomposition import PCA

# %%
pca = PCA(n_components=2)

# %%
pca.fit(data[factors])
# Out:
# PCA(n_components=2)

# %%
pca.explained_variance_ratio_
# Out:
# array([0.99756151, 0.0020628 ])

# %%
pca1 = pca.components_[0]
pca2 = pca.components_[1]

# %%
transformed_data = pca.transform(data[factors])

# %%
pc1 = transformed_data[:,0]
pc2 = transformed_data[:,1]

# %%
plt.scatter(pc1,pc2)

# %%
c = pca.inverse_transform(transformed_data[(transformed_data[:,0] > 0) & (transformed_data[:,1] > 250)])

# %%
factors
# Out:
# ['cylinders',
#  'displacement',
#  'horsepower',
#  'acceleration',
#  'weight',
#  'origin',
#  'model year']

# %%
c
# Out:
# array([[9.32016159e+00, 4.65727261e+02, 1.90441442e+02, 5.95699243e+00,
#         3.08611199e+03, 6.23550659e-01, 6.93571097e+01]])

# %%
data[(data['model year'] == 70) & (data.displacement > 400)]
# Out:
#                           mpg  cylinders  displacement  horsepower  weight  \
# car name
# ford galaxie 500         15.0          8         429.0       198.0    4341
# chevrolet impala         14.0          8         454.0       220.0    4354
# plymouth fury iii        14.0          8         440.0       215.0    4312
# pontiac catalina         14.0          8         455.0       225.0    4425
# buick estate wagon (sw)  14.0          8         455.0       225.0    3086
#
#                          acceleration  model year  origin Country_code  \
# car name
# ford galaxie 500                 10.0          70       1          USA
# chevrolet impala                  9.0          70       1          USA
# plymouth fury iii                 8.5          70       1          USA
# pontiac catalina                 10.0          70       1          USA
# buick estate wagon (sw)          10.0          70       1          USA
#
#                         Company_Name  Power_to_weight
# car name
# ford galaxie 500              subaru         0.034013
# chevrolet impala              subaru         0.037679
# plymouth fury iii             subaru         0.037181
# pontiac catalina              subaru         0.037917
# buick estate wagon (sw)       subaru         0.054369

# %%
cv_sets = KFold(n_splits=10, shuffle=True, random_state=100)
params = {'n_estimators' : list(range(40, 61)),
         'max_depth' : list(range(1, 10)),
         'learning_rate' : [0.1, 0.2, 0.3]}
grid = GridSearchCV(gb_regressor, params, cv=cv_sets, n_jobs=4)

# %%
grid = grid.fit(X_train, y_train)

# %%
grid.best_estimator_
# Out:
# GradientBoostingRegressor(learning_rate=0.3, max_depth=2, n_estimators=52)

# %%
gb_regressor_t = grid.best_estimator_

# %%
gb_regressor_t.fit(X_train,y_train)
# Out:
# GradientBoostingRegressor(learning_rate=0.3, max_depth=2, n_estimators=52)

# %%
y_predicted_gbr_t = gb_regressor_t.predict(X_test)

# %%
rmse = sqrt(mean_squared_error(y_true=y_test,y_pred=y_predicted_gbr_t))
rmse
# Out:
# 2.703175111310614

# %%
data.duplicated().any()
# Out:
# False
