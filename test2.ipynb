# %%
import numpy as np
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
ls
# Out:
# drive/  sample_data/

# %%
cd /content/drive/MyDrive/Colab Notebooks/GIthub/AI_School
# Out:
# /content/drive/MyDrive/Colab Notebooks/GIthub/AI_School

# %%
ls
# Out:
# README.md  test2.ipynb  test.ipynb  TP1/

# %%
arr1 = np.full(6, 7)

# %%
print(arr1)
# Out:
# [7 7 7 7 7 7]

# %%
arr2 = np.random.random(6)

# %%
print(arr2)
# Out:
# [0.87458277 0.49234861 0.24969257 0.01125524 0.67145795 0.12631952]

# %%
arr3 = np.arange(3, 17, 3)
print(arr3)
# Out:
# [ 3  6  9 12 15]

# %%
# !git ad
